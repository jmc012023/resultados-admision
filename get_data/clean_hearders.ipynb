# %%
import numpy as np
import pandas as pd

# %%
raw_descripton = pd.read_csv(
    "raw_description.csv"
)

raw_descripton
# Out:
#      Unnamed: 0           periodo  modalidad  \
# 0             0  ADMISIÓN 2019-II     CEPUNT
# 1             1  ADMISIÓN 2019-II     CEPUNT
# 2             2  ADMISIÓN 2019-II     CEPUNT
# 3             3  ADMISIÓN 2019-II  ORDINARIO
# 4             4  ADMISIÓN 2019-II  ORDINARIO
# ..          ...               ...        ...
# 198         198  ADMISION 2024-II  ORDINARIO
# 199         199  ADMISION 2024-II  ORDINARIO
# 200         200  ADMISION 2024-II  ORDINARIO
# 201         201  ADMISION 2024-II  ORDINARIO
# 202         202  ADMISION 2024-II  ORDINARIO
#
#                               descripcion  \
# 0              Resultados Cepunt Trujillo
# 1    Resultados Cepunt Valle Jequetepeque
# 2            Resultados Cepunt Huamachuco
# 3    Resultados Ordinario Área A Trujillo
# 4    Resultados Ordinario Área B Trujillo
# ..                                    ...
# 198               Áreas A y D: Huamachuco
# 199               Áreas B y C: Huamachuco
# ...
