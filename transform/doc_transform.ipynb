# %%
import numpy as np
import pandas as pd
import re

# %% [markdown]
# # GET RAW DATA

# %%
raw_data = pd.read_csv('results_by_links.csv')

raw_data
# Out:
#                                                all_result  n_df
# 0                                        CENTRO DE EST...     0
# 1        DIREC.DE SIST.y COMUNICACIONES               ...     0
# 2                   * UNIDAD P.A.D.*                  ...     0
# 3                                      RESULTADOS GENE...     0
# 4        =============================================...     0
# ...                                                   ...   ...
# 139354    0010 354870  PEREZ JOAQUIN MARCOS           ...   208
# 139355    0011 354470  AMADOR AVILA LUIS MARIO        ...   208
# 139356    0012 350570  CASTILLO LIÑAN CLEVER FELIPE   ...   208
# 139357    ********************************************...   208
# 139358        Nro TOTAL DE POSTULANTES =====>         ...   208
#
# [139359 rows x 2 columns]

# %% [markdown]
# ## DELETE AND REPLACE WHITE SPACES

# %%
many_white_spaces = re.compile(r'\s+')
one_white_space = ' '

raw_data['all_result'] = (
    raw_data['all_result']
    .str.replace(
        many_white_spaces,
        one_white_space,
        regex=True
    )
    .str.strip()
)

raw_data
# Out:
#                                                all_result  n_df
# 0       CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     0
# 1       DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...     0
# 2              * UNIDAD P.A.D.* << TRUJILLO >> 12/08/2018     0
# 3       RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...     0
# 4       ==============================================...     0
# ...                                                   ...   ...
# 139354  0010 354870 PEREZ JOAQUIN MARCOS 21.191 15.258...   208
# 139355  0011 354470 AMADOR AVILA LUIS MARIO 25.687 5.4...   208
# 139356  0012 350570 CASTILLO LIÑAN CLEVER FELIPE 19.56...   208
# 139357  **********************************************...   208
# 139358                 Nro TOTAL DE POSTULANTES =====> 77   208
#
# [139359 rows x 2 columns]

# %% [markdown]
# # ONLY RESULTS

# %%
fourt_digits = re.compile(r'^\d{4}')

filter_by_character = (
    raw_data['all_result']
    .str.contains(fourt_digits, regex=True)
)

raw_results = raw_data[filter_by_character]

raw_results
# Out:
#                                                all_result  n_df
# 8       0001 171558 RODRIGUEZ SANCHEZ ROSICELA ELIZABE...     0
# 9       0002 061758 LLANOS SOLIS KIMBERLYN YEI 37.504 ...     0
# 10      0003 178758 ALVA PEREZ TAMARA ANTONELLA 48.918...     0
# 11      0004 028758 URIOL FLORES LIZ ROCIO 39.342 57.7...     0
# 12      0005 170858 VASQUEZ GUERRA CESAR IVAN 35.462 5...     0
# ...                                                   ...   ...
# 139352  0008 353970 BRAVO LEZAMA DARIKS ALEXANDER 18.7...   208
# 139353  0009 353770 OTINIANO SANCHEZ HELEN NEFTALI 19....   208
# 139354  0010 354870 PEREZ JOAQUIN MARCOS 21.191 15.258...   208
# 139355  0011 354470 AMADOR AVILA LUIS MARIO 25.687 5.4...   208
# 139356  0012 350570 CASTILLO LIÑAN CLEVER FELIPE 19.56...   208
#
# [119027 rows x 2 columns]

# %% [markdown]
# # ONLY TITLES

# %%
raw_titles = raw_data[~filter_by_character]

raw_titles
# Out:
#                                                all_result  n_df
# 0       CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     0
# 1       DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...     0
# 2              * UNIDAD P.A.D.* << TRUJILLO >> 12/08/2018     0
# 3       RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...     0
# 4       ==============================================...     0
# ...                                                   ...   ...
# 139325                                   OR- I II PUNTAJE   208
# 139326  DEN CARNET APELIIDOS y NOMBRES SUMATIVO SUMATI...   208
# 139327  ==============================================...   208
# 139357  **********************************************...   208
# 139358                 Nro TOTAL DE POSTULANTES =====> 77   208
#
# [20332 rows x 2 columns]

# %% [markdown]
# # TRANSFORM TITLES

# %%
pag_number = re.compile(r'Pag\.\s\d+')
empty_string = ''

raw_titles.loc[:, 'all_result'] = (
    raw_titles['all_result']
    .str.replace(pag_number, empty_string, regex=True)
    .str.rstrip()
    )

raw_titles
# Out:
#                                                all_result  n_df
# 0       CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     0
# 1       DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...     0
# 2              * UNIDAD P.A.D.* << TRUJILLO >> 12/08/2018     0
# 3       RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...     0
# 4       ==============================================...     0
# ...                                                   ...   ...
# 139325                                   OR- I II PUNTAJE   208
# 139326  DEN CARNET APELIIDOS y NOMBRES SUMATIVO SUMATI...   208
# 139327  ==============================================...   208
# 139357  **********************************************...   208
# 139358                 Nro TOTAL DE POSTULANTES =====> 77   208
#
# [20332 rows x 2 columns]

# %%
titles_sep_sign = "="

def filter_group(dataframe_group):

    filter_title = (
        dataframe_group
        ['all_result']
        .str.startswith(titles_sep_sign)
    )

    index_value = (
        dataframe_group
        [filter_title]
        .index
        [0]
    )

    return dataframe_group.loc[:index_value - 1] # le puedes quitar el -1
    # para ver el = en el resultado

titles_group_by_n_df = (
    raw_titles
    .drop_duplicates(['all_result', 'n_df'])
    .groupby('n_df')
)

# %%
filtered_titles = map(lambda values: filter_group(values[1]), titles_group_by_n_df)
titles_before_equal_sign = pd.concat(filtered_titles)

titles_before_equal_sign.head(20)
# Out:
#                                              all_result  n_df
# 0     CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     0
# 1     DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...     0
# 2            * UNIDAD P.A.D.* << TRUJILLO >> 12/08/2018     0
# 3     RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...     0
# 3370  CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     1
# 3371  DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...     1
# 3372     * UNIDAD P.A.D.* << JEQUETEPEQUE >> 12/08/2018     1
# 3373  RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...     1
# 3678  CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     2
# 3679  DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...     2
# 3680       * UNIDAD P.A.D.* << HUAMACHUCO >> 12/08/2018     2
# 3681  RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...     2
# 3832             UNIVERSIDAD NACIONAL DE TRUJILLO - UNT     3
# 3833  DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION OR...     3
# 3834              * UNIDAD P.A.D.* GRUPO : A 22/09/2018     3
# 3835       RESULTADOS GENERALES POR ESCUELA PROFESIONAL     3
# 7235             UNIVERSIDAD NACIONAL DE TRUJILLO - UNT     4
# 7236  DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION OR...     4
# 7237              * UNIDAD P.A.D.* GRUPO : B 23/09/2018     4
# 7238       RESULTADOS GENERALES POR ESCUELA PROFESIONAL     4

# %%
n_titles_per_df = titles_before_equal_sign.groupby("n_df").count()

n_titles_per_df
# Out:
#       all_result
# n_df
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4
# ...          ...
# 204            3
# 205            3
# 206            3
# 207            3
# 208            3
#
# [209 rows x 1 columns]

# %%
titles_before_equal_sign = pd.merge(titles_before_equal_sign, n_titles_per_df, left_on='n_df', right_on='n_df')

titles_before_equal_sign
# Out:
#                                           all_result_x  n_df  all_result_y
# 0    CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     0             4
# 1    DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...     0             4
# 2           * UNIDAD P.A.D.* << TRUJILLO >> 12/08/2018     0             4
# 3    RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...     0             4
# 4    CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     1             4
# ..                                                 ...   ...           ...
# 725   21/07/2024 EXAMENES SUMATIVOS 2025- I - CEPUNT I   207             3
# 726  RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...   207             3
# 727  OFICINA DE TECNOLOGIAS DE LA INFORMACION DE LA...   208             3
# 728   21/07/2024 EXAMENES SUMATIVOS 2025- I - CEPUNT I   208             3
# 729  RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...   208             3
#
# [730 rows x 3 columns]

# %%
def add_serie(df):
    max_value = df['all_result_y'].max()
    df['aux'] = range(max_value)
    return df

# %%
titles_with_sequence = map(lambda values: add_serie(values[1]), titles_before_equal_sign.groupby("n_df"))
titles_before_equal_sign = pd.concat(titles_with_sequence)

titles_before_equal_sign
# Out:
#                                           all_result_x  n_df  all_result_y  \
# 0    CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     0             4
# 1    DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...     0             4
# 2           * UNIDAD P.A.D.* << TRUJILLO >> 12/08/2018     0             4
# 3    RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...     0             4
# 4    CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     1             4
# ..                                                 ...   ...           ...
# 725   21/07/2024 EXAMENES SUMATIVOS 2025- I - CEPUNT I   207             3
# 726  RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...   207             3
# 727  OFICINA DE TECNOLOGIAS DE LA INFORMACION DE LA...   208             3
# 728   21/07/2024 EXAMENES SUMATIVOS 2025- I - CEPUNT I   208             3
# 729  RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...   208             3
#
#      aux
# 0      0
# 1      1
# 2      2
# 3      3
# 4      0
# ..   ...
# 725    1
# 726    2
# 727    0
# 728    1
# 729    2
#
# [730 rows x 4 columns]

# %%
unstacked_titles = (
    titles_before_equal_sign
    .loc[:, ['n_df', 'aux', 'all_result_x']]
    .set_index(['n_df', 'aux'])
    .unstack()
    .droplevel(['aux'], axis=1)
)

unstacked_titles.columns = ['first', 'second', 'third', 'fourth']

unstacked_titles
# Out:
#                                                   first  \
# n_df
# 0     CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...
# 1     CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...
# 2     CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...
# 3                UNIVERSIDAD NACIONAL DE TRUJILLO - UNT
# 4                UNIVERSIDAD NACIONAL DE TRUJILLO - UNT
# ...                                                 ...
# 204   OFICINA DE TECNOLOGIAS DE LA INFORMACION DE LA...
# 205   OFICINA DE TECNOLOGIAS DE LA INFORMACION DE LA...
# 206   OFICINA DE TECNOLOGIAS DE LA INFORMACION DE LA...
# 207   OFICINA DE TECNOLOGIAS DE LA INFORMACION DE LA...
# 208   OFICINA DE TECNOLOGIAS DE LA INFORMACION DE LA...
#
#                                                  second  \
# n_df
# 0     DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...
# 1     DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...
# 2     DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...
# 3     DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION OR...
# 4     DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION OR...
# ...                                                 ...
# 204     17/03/2024 EXAMEN DE ADMISION ORDINARIO 2024-II
# 205     17/03/2024 EXAMEN DE ADMISION ORDINARIO 2024-II
# 206    21/07/2024 EXAMENES SUMATIVOS 2025- I - CEPUNT I
# 207    21/07/2024 EXAMENES SUMATIVOS 2025- I - CEPUNT I
# 208    21/07/2024 EXAMENES SUMATIVOS 2025- I - CEPUNT I
#
#                                                   third  \
# n_df
# 0            * UNIDAD P.A.D.* << TRUJILLO >> 12/08/2018
# 1        * UNIDAD P.A.D.* << JEQUETEPEQUE >> 12/08/2018
# 2          * UNIDAD P.A.D.* << HUAMACHUCO >> 12/08/2018
# 3                 * UNIDAD P.A.D.* GRUPO : A 22/09/2018
# 4                 * UNIDAD P.A.D.* GRUPO : B 23/09/2018
# ...                                                 ...
# 204   RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...
# 205   RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...
# 206   RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...
# 207   RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...
# 208   RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...
#
#                                                  fourth
# n_df
# 0     RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...
# 1     RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...
# 2     RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...
# 3          RESULTADOS GENERALES POR ESCUELA PROFESIONAL
# 4          RESULTADOS GENERALES POR ESCUELA PROFESIONAL
# ...                                                 ...
# 204                                                 NaN
# 205                                                 NaN
# 206                                                 NaN
# 207                                                 NaN
# 208                                                 NaN
#
# [209 rows x 4 columns]

# %% [markdown]
# ## TRANSFORM SECOND COLUMN

# %%
unstacked_titles['second'].value_counts().sort_index(ascending=False).head(49)
# Out:
# second
# OFI.DE TECNOLOG.DE LA INFORMAC. EXAMENES SUMATIVOS 2024- I - CEPUNT I                 3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2024-I                       3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2024- I - TRUJILLO           3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2023-II - V A L L E          3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2023-II - TRUJILLO           3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2023-II - STGO.DE CHUCO      1
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2023-II - HUAMACHUCO         3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2023-I                       3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2023- I - TRUJILLO           3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2022-II - V A L L E          3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2022-II - TRUJILLO           3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2022-II - STGO.DE CHUCO      1
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2022-II - HUAMACHUCO         3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2022-I                       3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2022- I - TRUJILLO           3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2024- I * TRUJILLO      2
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2023-II * V A L L E     2
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2023-II * TRUJILLO      3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2023-II * HUAMACHUCO    1
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2023- I * TRUJILLO      2
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2022-II * V A L L E     1
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2022-II * TRUJILLO      4
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2022-II * HUAMACHUCO    1
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2022- I * TRUJILLO      2
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2023-II - CEPUNT II * V A L L E        3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2023-II - CEPUNT II * TRUJILLO         3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2023-II - CEPUNT II * HUAMACHUCO       3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2023- I - CEPUNT I * V A L L E         3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2023- I - CEPUNT I * TRUJILLO          3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2023- I - CEPUNT I * HUAMACHUCO        3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2022-II - CEPUNT II * V A L L E        3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2022-II - CEPUNT II * TRUJILLO         3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2022-II - CEPUNT II * HUAMACHUCO       3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2022- I - CEPUNT I * V A L L E         3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2022- I - CEPUNT I * TRUJILLO          3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2022- I - CEPUNT I * HUAMACHUCO        3
# DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATIVOS 2020-II - CEPUNT II                 3
# DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATIVOS 2020- I - CEPUNT I                  3
# DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATIVOS 2019-II - CEPUNT II                 3
# DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATIVOS 2019- I - CEPUNT I                  3
# DIREC.DE SIST.y COMUNICAC. EXAMEN DE ADMISION ORDINARIO 2021-II * STGO.DE CHUCO       1
# DIREC.DE SIST.y COMUNICAC. EXAMEN DE ADMISION ORDINARIO 2020-II * STGO.DE CHUCO       1
# DIREC.DE SIST.y COMUNICAC. EXAMEN DE ADMISION ORDINARIO 2019-II * STGO.DE CHUCO       1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021-II - TRUJILLO              3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021-II * JEQUETEPEQUE          3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021- I - TRUJILLO              4
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021- I * TRUJILLO              4
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2020-II - TRUJILLO              2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2020-II * JEQUETEPEQUE          2
# Name: count, dtype: int64

# %%
unstacked_titles['second'].value_counts().sort_index(ascending=False).tail(50)
# Out:
# second
# DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATIVOS 2019- I - CEPUNT I                  3
# DIREC.DE SIST.y COMUNICAC. EXAMEN DE ADMISION ORDINARIO 2021-II * STGO.DE CHUCO       1
# DIREC.DE SIST.y COMUNICAC. EXAMEN DE ADMISION ORDINARIO 2020-II * STGO.DE CHUCO       1
# DIREC.DE SIST.y COMUNICAC. EXAMEN DE ADMISION ORDINARIO 2019-II * STGO.DE CHUCO       1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021-II - TRUJILLO              3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021-II * JEQUETEPEQUE          3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021- I - TRUJILLO              4
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021- I * TRUJILLO              4
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2020-II - TRUJILLO              2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2020-II * JEQUETEPEQUE          2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2020- I - TRUJILLO              2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2020- I * TRUJILLO              2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2019-II - TRUJILLO              2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2019-II * JEQUETEPEQUE          2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2019- I - TRUJILLO              2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2019- I * TRUJILLO              2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2021-II * TRUJILLO         1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2021-II * HUAMACHUCO       1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2021- I * TRUJILLO         1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2020-II * TRUJILLO         1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2020-II * STGO.DE CHUCO    1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2020-II * HUAMACHUCO       1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2020- I * TRUJILLO         1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2019-II * TRUJILLO         1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2019-II * STGO.DE CHUCO    1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2019-II * HUAMACHUCO       1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2019- I * TRUJILLO         1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2021-II - CEPUNT II * TRUJILLO            3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2021-II - CEPUNT II * HUAMACHUCO          3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2021-II * TRUJILLO                        2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2021- I - CEPUNT I * TRUJILLO             3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2021- I - CEPUNT I * HUAMACHUCO           3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2020-II * TRUJILLO                        3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2020- I * TRUJILLO                        1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2019-II * TRUJILLO                        3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2019- I * TRUJILLO                        1
# DIREC.DE SIS.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2021-II * JEQUETEPEQUE      1
# DIREC.DE SIS.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2020-II * JEQUETEPEQUE      1
# DIREC.DE SIS.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2019-II * JEQUETEPEQUE      1
# DIREC.DE SIS.y COMUNIC. EXAMEN DE ADMISION 2021-II - CEPUNT II * JEQUETEPEQUE         3
# DIREC.DE SIS.y COMUNIC. EXAMEN DE ADMISION 2021- I - CEPUNT I * JEQUETEPEQUE          3
# DIR.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021-II * HUAMACHUCO              3
# DIR.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2020-II * HUAMACHUCO              2
# DIR.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2019-II * HUAMACHUCO              2
# 21/07/2024 EXAMENES SUMATIVOS 2025- I - CEPUNT I                                      3
# 18/02/2024 EXAMENES SUMATIVOS 2024-II - CEPUNT II                                     3
# 17/03/2024 EXAMEN DE ADMISION ORDINARIO 2024-II                                       4
# 16/03/2024 EXAMEN DE ADMISION ORDINARIO 2024-II                                       3
# 03/03/2024 EXAMEN DE ADMISION EXTRAORDINARIO 2024-II * TRUJILLO                       3
# 03/03/2024 EXAMEN DE ADMISION EXTRAORDINARIO 2024-II                                  4
# Name: count, dtype: int64

# %% [markdown]
# ### SECOND COLUMN DATES

# %%
valid_date = re.compile(r'(\d\d/\d\d/\d+)')

second_date = (
    unstacked_titles
    ['second']
    .str.extract(valid_date)
    [0]
    # .value_counts()
    # .sum()
)

second_date.value_counts()
# Out:
# 0
# 03/03/2024    7
# 17/03/2024    4
# 18/02/2024    3
# 16/03/2024    3
# 21/07/2024    3
# Name: count, dtype: int64

# %% [markdown]
# ## TRANSFORM THIRD COLUMN

# %%
unstacked_titles['third'].value_counts().sort_index().head(60)
# Out:
# third
# * AREA P.A.D.* << HUAMACHUCO >> 20/08/2023                                                           1
# * AREA P.A.D.* << TRUJILLO >> 20/08/2023                                                             1
# * AREA P.A.D.* << V A L L E >> 20/08/2023                                                            1
# * AREA P.A.D.* AREA * A 30/09/2023                                                                   1
# * AREA P.A.D.* AREA - D 23/09/2023                                                                   1
# * AREA P.A.D.* AREA : A 07/04/2022                                                                   3
# * AREA P.A.D.* AREA : A 21/10/2022                                                                   1
# * AREA P.A.D.* AREA : A 24/03/2023                                                                   3
# * AREA P.A.D.* AREA : A 28/10/2021                                                                   1
# * AREA P.A.D.* AREA : B 08/04/2022                                                                   4
# * AREA P.A.D.* AREA : B 22/10/2022                                                                   1
# * AREA P.A.D.* AREA : B 25/03/2023                                                                   4
# * AREA P.A.D.* AREA : B 29/10/2021                                                                   1
# * AREA P.A.D.* AREA : C-D 09/04/2022                                                                 2
# * AREA P.A.D.* AREA : C-D 23/10/2022                                                                 1
# * AREA P.A.D.* AREA : C-D 26/03/2023                                                                 2
# * AREA P.A.D.* AREA : C-D 30/10/2021                                                                 1
# * AREA P.A.D.* AREA : D 09/04/2022                                                                   1
# * AREA P.A.D.* AREA : D 26/03/2023                                                                   1
# * AREA P.A.D.* AREAS * B - C 24/09/2023                                                              1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 21/10/2022                                       1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 22/10/2022                                       1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 23/09/2023                                       1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 23/10/2022                                       1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 24/09/2023                                       1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 28/10/2021                                       1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 29/10/2021                                       1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 30/09/2023                                       1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 30/10/2021                                       1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA-A 08/10/2021                      3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA-A 10/03/2023                      3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA-A 15/09/2022                      3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA-A 17/03/2022                      3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA-B 08/10/2021                      3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA-B 11/03/2023                      3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA-B 16/09/2022                      3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA-B 18/03/2022                      3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREAS C-D 09/10/2021                   3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREAS C-D 12/03/2023                   3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREAS C-D 17/09/2022                   3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREAS C-D 19/03/2022                   3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - DEPORTISTAS CALIFICADOS 26/02/2022     1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - DISCAPACITADOS 03/09/2023              1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - DISCAPACITADOS 10/09/2022              1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - DISCAPACITADOS 11/02/2023              1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - DISCAPACITADOS 21/09/2021              1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - DISCAPACITADOS 26/02/2022              1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - VICTIMAS DE LA VIOLENCIA 11/02/2023    2
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - VICTIMAS DE LA VIOLENCIA 26/02/2022    1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL 03/09/2023                               1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL 10/09/2022                               1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL 11/02/2023                               3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL 21/09/2021                               1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL 26/02/2022                               3
# * UNIDAD P.A.D.* << HUAMACHUCO >> 09/02/2020                                                         1
# * UNIDAD P.A.D.* << HUAMACHUCO >> 10/02/2019                                                         1
# * UNIDAD P.A.D.* << HUAMACHUCO >> 12/08/2018                                                         1
# * UNIDAD P.A.D.* << HUAMACHUCO >> 18/08/2019                                                         1
# * UNIDAD P.A.D.* << JEQUETEPEQUE >> 09/02/2020                                                       1
# * UNIDAD P.A.D.* << JEQUETEPEQUE >> 10/02/2019                                                       1
# Name: count, dtype: int64

# %%
unstacked_titles['third'].value_counts().sort_index().tail(60)
# Out:
# third
# * UNIDAD P.A.D.* << JEQUETEPEQUE >> 12/08/2018                                             1
# * UNIDAD P.A.D.* << JEQUETEPEQUE >> 18/08/2019                                             1
# * UNIDAD P.A.D.* << TRUJILLO >> 09/02/2020                                                 1
# * UNIDAD P.A.D.* << TRUJILLO >> 10/02/2019                                                 1
# * UNIDAD P.A.D.* << TRUJILLO >> 12/08/2018                                                 1
# * UNIDAD P.A.D.* << TRUJILLO >> 18/08/2019                                                 1
# * UNIDAD P.A.D.* AREA : A 02/06/2021                                                       3
# * UNIDAD P.A.D.* AREA : A 02/12/2020                                                       1
# * UNIDAD P.A.D.* AREA : B 03/12/2020                                                       1
# * UNIDAD P.A.D.* AREA : B 28/05/2021                                                       4
# * UNIDAD P.A.D.* AREA : C 04/12/2020                                                       1
# * UNIDAD P.A.D.* AREA : C-D 29/05/2021                                                     2
# * UNIDAD P.A.D.* AREA : D 05/12/2020                                                       1
# * UNIDAD P.A.D.* AREA : D 29/05/2021                                                       1
# * UNIDAD P.A.D.* GRUPO : A 07/03/2020                                                      4
# * UNIDAD P.A.D.* GRUPO : A 09/03/2019                                                      3
# * UNIDAD P.A.D.* GRUPO : A 21/09/2019                                                      1
# * UNIDAD P.A.D.* GRUPO : A 22/09/2018                                                      1
# * UNIDAD P.A.D.* GRUPO : A y B 09/03/2019                                                  1
# * UNIDAD P.A.D.* GRUPO : B 08/03/2020                                                      3
# * UNIDAD P.A.D.* GRUPO : B 10/03/2019                                                      3
# * UNIDAD P.A.D.* GRUPO : B 22/09/2019                                                      1
# * UNIDAD P.A.D.* GRUPO : B 23/09/2018                                                      1
# * UNIDAD P.A.D.* Modalidad : DEPORTISTAS CALIFICADOS 23/02/2020                            1
# * UNIDAD P.A.D.* Modalidad : DEPORTISTAS CALIFICADOS 24/02/2019                            1
# * UNIDAD P.A.D.* Modalidad : DISCAPACITADOS 08/09/2019                                     1
# * UNIDAD P.A.D.* Modalidad : DISCAPACITADOS 12/05/2021                                     1
# * UNIDAD P.A.D.* Modalidad : DISCAPACITADOS 23/02/2020                                     1
# * UNIDAD P.A.D.* Modalidad : DISCAPACITADOS 24/02/2019                                     1
# * UNIDAD P.A.D.* Modalidad : DISCAPACITADOS 26/08/2018                                     1
# * UNIDAD P.A.D.* Modalidad : VICTIMAS DE LA VIOLENCIA 12/05/2021                           1
# * UNIDAD P.A.D.* Modalidad : VICTIMAS DE LA VIOLENCIA 23/02/2020                           1
# * UNIDAD P.A.D.* Modalidad : VICTIMAS DE LA VIOLENCIA 24/02/2019                           1
# * UNIDAD P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 02/12/2020                           1
# * UNIDAD P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 03/12/2020                           1
# * UNIDAD P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 04/12/2020                           1
# * UNIDAD P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 05/12/2020                           1
# * UNIDAD P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 21/09/2019                           1
# * UNIDAD P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 22/09/2018                           1
# * UNIDAD P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 22/09/2019                           1
# * UNIDAD P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 23/09/2018                           1
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA A 05/11/2020          3
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA A 13/05/2021          3
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA B 06/11/2020          3
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA B 14/05/2021          3
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA C-D 07/11/2020        3
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA C-D 15/05/2021        3
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - GRUPOS A y B 08/09/2019    1
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - GRUPOS A y B 23/02/2020    4
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - GRUPOS A y B 24/02/2019    4
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - GRUPOS A y B 26/08/2018    1
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL 12/05/2021                   3
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL 21/11/2020                   1
# RESULTADOS GENERALES POR ESCUELA PROFESIONAL * DEPORTISTAS CALIFICADOS                     1
# RESULTADOS GENERALES POR ESCUELA PROFESIONAL * DISCAPACITADOS                              1
# RESULTADOS GENERALES POR ESCUELA PROFESIONAL * HUAMACHUCO                                  5
# RESULTADOS GENERALES POR ESCUELA PROFESIONAL * STGO.DE CHUCO                               2
# RESULTADOS GENERALES POR ESCUELA PROFESIONAL * TRUJILLO                                    5
# RESULTADOS GENERALES POR ESCUELA PROFESIONAL * V A L L E                                   5
# RESULTADOS GENERALES POR ESCUELA PROFESIONAL * VICT.DE LA VIOLENCIA                        1
# Name: count, dtype: int64

# %% [markdown]
# ### THIRD COLUMN DATES

# %%
nombre = 'third'

third_date = (
    unstacked_titles
    [nombre]
    .str.extract(valid_date)
    [0]
    # .value_counts()
    # .sum()
)

third_date.value_counts()
# Out:
# 0
# 23/02/2020    7
# 24/02/2019    7
# 08/10/2021    6
# 11/02/2023    6
# 26/02/2022    6
#              ..
# 21/09/2021    2
# 02/12/2020    2
# 03/12/2020    2
# 23/09/2023    2
# 21/11/2020    1
# Name: count, Length: 63, dtype: int64

# %% [markdown]
# ## JOIN COLUMN TITLES

# %%
# second_date
# second_users doesn't have users

# third_date

# third_tests doesn't have tests

# fourth_areas

# %%
date_title = (
    second_date
    .str.cat(third_date, na_rep=empty_string)
    .replace(empty_string, np.nan, regex=False)
 )

date_title.name = "date"
date_title
# Out:
# n_df
# 0      12/08/2018
# 1      12/08/2018
# 2      12/08/2018
# 3      22/09/2018
# 4      23/09/2018
#           ...
# 204    17/03/2024
# 205    17/03/2024
# 206    21/07/2024
# 207    21/07/2024
# 208    21/07/2024
# Name: date, Length: 209, dtype: object

# %% [markdown]
# # TRANSFORM RESULTS

# %% [markdown]
# ## NAMES

# %%
valid_name = re.compile(r'\s(\D+[0]?\D+[0]?)\s-?\d')

names = (
    raw_results
    ['all_result']
    .str.extract(valid_name)
    [0]
    .str.strip()
    .str.replace('0 0', '', regex=False)
    .str.rstrip()
    .str.replace('0', 'O', regex=False)
    .str.lower()
)

names
# Out:
# 8         rodriguez sanchez rosicela elizabeth
# 9                   llanos solis kimberlyn yei
# 10                 alva perez tamara antonella
# 11                      uriol flores liz rocio
# 12                   vasquez guerra cesar ivan
#                           ...
# 139352           bravo lezama dariks alexander
# 139353          otiniano sanchez helen neftali
# 139354                    perez joaquin marcos
# 139355                 amador avila luis mario
# 139356            castillo liñan clever felipe
# Name: 0, Length: 119027, dtype: object

# %% [markdown]
# ## GRADES

# %%
valid_grades = re.compile(r'(-?\d+\.\d+)')

grades = (
    raw_results
    ['all_result']
    .str.extractall(valid_grades)
    .unstack()
    .droplevel(level=0, axis=1)
)

grades
# Out:
# match        0       1        2        3       4
# 8       41.577  78.261  126.368  246.206  94.842
# 9       37.504  67.242  109.044  213.790  94.842
# 10      48.918  53.192  109.036  211.146  94.842
# 11      39.342  57.783  102.429  199.554  94.842
# 12      35.462  50.730  109.548  195.740  94.842
# ...        ...     ...      ...      ...     ...
# 139352  18.748  24.420   43.168      NaN     NaN
# 139353  19.980  20.180   40.160      NaN     NaN
# 139354  21.191  15.258   36.449      NaN     NaN
# 139355  25.687   5.483   31.170      NaN     NaN
# 139356  19.567   0.000   19.567      NaN     NaN
#
# [119027 rows x 5 columns]

# %% [markdown]
# ## SCHOOL AND DETAILS

# %%
after_grades = re.compile(r'(\.\d+\s[A-Z].*)')
digits = re.compile(r'\.\d+\s')
empty_string = ''

school_and_details = (
        raw_results
        ['all_result']
        .str.extract(after_grades)
        [0]
        .str.replace(digits, empty_string, regex=True)
)

school_and_details
# Out:
# 8         SI ADMINISTRACION
# 9         SI ADMINISTRACION
# 10        SI ADMINISTRACION
# 11        SI ADMINISTRACION
# 12        SI ADMINISTRACION
#                 ...
# 139352      ING.DE MINAS NO
# 139353      ING.DE MINAS NO
# 139354      ING.DE MINAS NO
# 139355      ING.DE MINAS NO
# 139356      ING.DE MINAS NO
# Name: 0, Length: 119027, dtype: object

# %% [markdown]
# ### DETAILS

# %%
valid_result = re.compile(r'(INGRESA.*|NO\sINGRESA.*|ING\.\s?2.*|AUSENTE.*|ANULADO.*|^SI\s|^NO\s|\sSI$|\sNO$)')
possitive_pattern = re.compile(r'INGRESA([\w\s-]+)?')
negative_pattern = re.compile(r'NO\D+')
positive_result = 'SI'
negative_result = 'NO'
ingresa = 'INGRESA'
no_ingresa = 'NO INGRESA'

details = (
        school_and_details
        .str.extract(valid_result)
        [0]
        .str.strip()
        .str.replace(negative_pattern, negative_result, regex=True)
        .str.replace(possitive_pattern, positive_result, regex=True)
        .str.replace(positive_result, ingresa, regex=False)
        .str.replace(negative_result, no_ingresa, regex=False)
        .str.replace('.', '', regex=False)
        .str.replace('ING 2-OPC', 'SEGUNDA OPC', regex=False)
        .str.lower()
        .str.strip()
)

details
# Out:
# 8            ingresa
# 9            ingresa
# 10           ingresa
# 11           ingresa
# 12           ingresa
#              ...
# 139352    no ingresa
# 139353    no ingresa
# 139354    no ingresa
# 139355    no ingresa
# 139356    no ingresa
# Name: 0, Length: 119027, dtype: object

# %%
details.value_counts()
# Out:
# 0
# no ingresa     98171
# ingresa        16268
# ausente         3003
# segunda opc     1564
# anulado           20
# Name: count, dtype: int64

# %%
details[details.isnull()]
# Out:
# 88692    NaN
# Name: 0, dtype: object

# %% [markdown]
# ### SCHOOL

# %%
valid_result2 = re.compile(r'INGRESA.*|NO\sINGRESA.*|ING\.\s?2.*|AUSENTE.*|ANULADO.*|^SI\s|^NO\s|\sSI$|\sNO$')

school = (
    school_and_details
    .str.replace(valid_result2, empty_string, regex=True)
    .str.upper()
    .str.strip()
    .str.replace(".", " ", regex=False)    
    .str.replace(":", " ", regex=False)   
    .str.strip()    
    .str.replace(r"\s+", " ", regex=True)   
    .str.lower()   
)

school
# Out:
# 8         administracion
# 9         administracion
# 10        administracion
# 11        administracion
# 12        administracion
#                ...
# 139352      ing de minas
# 139353      ing de minas
# 139354      ing de minas
# 139355      ing de minas
# 139356      ing de minas
# Name: 0, Length: 119027, dtype: object

# %%
school.value_counts()
# Out:
# 0
# medicina              21189
# derecho y cc pp        8464
# ing industrial         8105
# administracion         7715
# enfermeria             6430
# ing civil              5918
# ing de sistemas        5253
# contabil y finan       5250
# arquitectura y urb     4676
# trabajo social         3341
# ing ambiental          3038
# ing de minas           2952
# farmacia y bbqq        2734
# ing mecatronica        2550
# economia               2476
# ing agroindustrial     2163
# informatica            2036
# ing mecanica           1970
# estomatologia          1959
# educacion inicial      1940
# ing quimica            1749
# ccas comunicacion      1738
# ed sec idiomas         1435
# ccas biologicas        1311
# microbiol y paras      1137
# cc politica y gob       943
# agronomia               925
# ing metalurgica         885
# derecho                 869
# educacion primaria      805
# turismo                 758
# ed sec lengua           697
# ing agronomica          656
# ing agricola            649
# ing de materiales       585
# ed sec filosofia        546
# ed sec historia         457
# zootecnia               438
# antropologia            390
# estadistica             338
# arqueologia             278
# fisica                  218
# ed sec matematica       205
# matematicas             192
# ing zootecnista         176
# biologia pesquera       119
# historia                118
# ed sec lengua y l       115
# ed sec hist y geo        61
# pesqueria                47
# ed sec cc matemat        25
# ed sec cc natural         3
# Name: count, dtype: int64

# %% [markdown]
# ## JOIN RESULTS

# %%
column_results = ['names', 'one', 'two', 'three', 'four', 'five', 'career', 'status', 'n_df']

results = pd.concat(
    [
        names,
        grades,
        school,
        details,
        raw_results['n_df']
    ],
    axis=1    
)

results.columns = column_results

results
# Out:
#                                        names     one     two    three  \
# 8       rodriguez sanchez rosicela elizabeth  41.577  78.261  126.368
# 9                 llanos solis kimberlyn yei  37.504  67.242  109.044
# 10               alva perez tamara antonella  48.918  53.192  109.036
# 11                    uriol flores liz rocio  39.342  57.783  102.429
# 12                 vasquez guerra cesar ivan  35.462  50.730  109.548
# ...                                      ...     ...     ...      ...
# 139352         bravo lezama dariks alexander  18.748  24.420   43.168
# 139353        otiniano sanchez helen neftali  19.980  20.180   40.160
# 139354                  perez joaquin marcos  21.191  15.258   36.449
# 139355               amador avila luis mario  25.687   5.483   31.170
# 139356          castillo liñan clever felipe  19.567   0.000   19.567
#
#            four    five          career      status  n_df
# 8       246.206  94.842  administracion     ingresa     0
# 9       213.790  94.842  administracion     ingresa     0
# 10      211.146  94.842  administracion     ingresa     0
# 11      199.554  94.842  administracion     ingresa     0
# 12      195.740  94.842  administracion     ingresa     0
# ...         ...     ...             ...         ...   ...
# 139352      NaN     NaN    ing de minas  no ingresa   208
# 139353      NaN     NaN    ing de minas  no ingresa   208
# 139354      NaN     NaN    ing de minas  no ingresa   208
# 139355      NaN     NaN    ing de minas  no ingresa   208
# 139356      NaN     NaN    ing de minas  no ingresa   208
#
# [119027 rows x 9 columns]

# %% [markdown]
# # JOIN TITLES WITH RESULTS

# %%
results_with_dates = pd.merge(
    results,
    date_title,
    left_on='n_df',
    right_index=True
)

results_with_dates
# Out:
#                                        names     one     two    three  \
# 8       rodriguez sanchez rosicela elizabeth  41.577  78.261  126.368
# 9                 llanos solis kimberlyn yei  37.504  67.242  109.044
# 10               alva perez tamara antonella  48.918  53.192  109.036
# 11                    uriol flores liz rocio  39.342  57.783  102.429
# 12                 vasquez guerra cesar ivan  35.462  50.730  109.548
# ...                                      ...     ...     ...      ...
# 139352         bravo lezama dariks alexander  18.748  24.420   43.168
# 139353        otiniano sanchez helen neftali  19.980  20.180   40.160
# 139354                  perez joaquin marcos  21.191  15.258   36.449
# 139355               amador avila luis mario  25.687   5.483   31.170
# 139356          castillo liñan clever felipe  19.567   0.000   19.567
#
#            four    five          career      status  n_df        date
# 8       246.206  94.842  administracion     ingresa     0  12/08/2018
# 9       213.790  94.842  administracion     ingresa     0  12/08/2018
# 10      211.146  94.842  administracion     ingresa     0  12/08/2018
# 11      199.554  94.842  administracion     ingresa     0  12/08/2018
# 12      195.740  94.842  administracion     ingresa     0  12/08/2018
# ...         ...     ...             ...         ...   ...         ...
# 139352      NaN     NaN    ing de minas  no ingresa   208  21/07/2024
# 139353      NaN     NaN    ing de minas  no ingresa   208  21/07/2024
# 139354      NaN     NaN    ing de minas  no ingresa   208  21/07/2024
# 139355      NaN     NaN    ing de minas  no ingresa   208  21/07/2024
# 139356      NaN     NaN    ing de minas  no ingresa   208  21/07/2024
#
# [119027 rows x 10 columns]

# %% [markdown]
# # READ DESCRIPTION DATA

# %%
description = pd.read_csv("cleaned_wp_content.csv")
description
# Out:
#      test_type  year_period period  mod               place  \
# 0       cepunt         2019      i  NaN            trujillo
# 1       cepunt         2019      i  NaN  valle jequetepeque
# 2       cepunt         2019      i  NaN          huamachuco
# 3    ordinario         2019      i  NaN            trujillo
# 4    ordinario         2019      i  NaN            trujillo
# ..         ...          ...    ...  ...                 ...
# 204  ordinario         2024     ii  NaN  valle jequetepeque
# 205  ordinario         2024     ii  NaN   santiago de chuco
# 206     cepunt         2025      i  NaN            trujillo
# 207     cepunt         2025      i  NaN  valle jequetepeque
# 208     cepunt         2025      i  NaN          huamachuco
#
#                                                   link
# 0    http://admisionunt.info/docs/padrones/20191/20...
# 1    http://admisionunt.info/docs/padrones/20191/20...
# 2    http://admisionunt.info/docs/padrones/20191/20...
# 3    http://admisionunt.info/docs/padrones/20191/20...
# 4    http://admisionunt.info/docs/padrones/20191/20...
# ..                                                 ...
# 204  https://unitru.edu.pe/webfiles///Convocatoria/...
# 205  https://unitru.edu.pe/webfiles///Convocatoria/...
# 206  https://unitru.edu.pe/webfiles///Convocatoria/...
# 207  https://unitru.edu.pe/webfiles///Convocatoria/...
# 208  https://unitru.edu.pe/webfiles///Convocatoria/...
#
# [209 rows x 6 columns]

# %%
##############
description['mod'].value_counts()
# Out:
# mod
# excelencia                   23
# 5to secundaria               17
# personas con discapacidad    11
# victimas de la violencia      7
# deportistas calificados       4
# Name: count, dtype: int64

# %% [markdown]
# # JOIN RESULTS WITH DESCRIPTION

# %%
new_combined_data = (
    pd.merge(
        results_with_dates,
        description,
        left_on='n_df',
        right_index=True
        )
        )

new_combined_data
# Out:
#                                        names     one     two    three  \
# 8       rodriguez sanchez rosicela elizabeth  41.577  78.261  126.368
# 9                 llanos solis kimberlyn yei  37.504  67.242  109.044
# 10               alva perez tamara antonella  48.918  53.192  109.036
# 11                    uriol flores liz rocio  39.342  57.783  102.429
# 12                 vasquez guerra cesar ivan  35.462  50.730  109.548
# ...                                      ...     ...     ...      ...
# 139352         bravo lezama dariks alexander  18.748  24.420   43.168
# 139353        otiniano sanchez helen neftali  19.980  20.180   40.160
# 139354                  perez joaquin marcos  21.191  15.258   36.449
# 139355               amador avila luis mario  25.687   5.483   31.170
# 139356          castillo liñan clever felipe  19.567   0.000   19.567
#
#            four    five          career      status  n_df        date  \
# 8       246.206  94.842  administracion     ingresa     0  12/08/2018
# 9       213.790  94.842  administracion     ingresa     0  12/08/2018
# 10      211.146  94.842  administracion     ingresa     0  12/08/2018
# 11      199.554  94.842  administracion     ingresa     0  12/08/2018
# 12      195.740  94.842  administracion     ingresa     0  12/08/2018
# ...         ...     ...             ...         ...   ...         ...
# 139352      NaN     NaN    ing de minas  no ingresa   208  21/07/2024
# 139353      NaN     NaN    ing de minas  no ingresa   208  21/07/2024
# 139354      NaN     NaN    ing de minas  no ingresa   208  21/07/2024
# 139355      NaN     NaN    ing de minas  no ingresa   208  21/07/2024
# 139356      NaN     NaN    ing de minas  no ingresa   208  21/07/2024
#
#        test_type  year_period period  mod       place  \
# 8         cepunt         2019      i  NaN    trujillo
# 9         cepunt         2019      i  NaN    trujillo
# 10        cepunt         2019      i  NaN    trujillo
# 11        cepunt         2019      i  NaN    trujillo
# 12        cepunt         2019      i  NaN    trujillo
# ...          ...          ...    ...  ...         ...
# 139352    cepunt         2025      i  NaN  huamachuco
# 139353    cepunt         2025      i  NaN  huamachuco
# 139354    cepunt         2025      i  NaN  huamachuco
# 139355    cepunt         2025      i  NaN  huamachuco
# 139356    cepunt         2025      i  NaN  huamachuco
#
#                                                      link
# 8       http://admisionunt.info/docs/padrones/20191/20...
# 9       http://admisionunt.info/docs/padrones/20191/20...
# 10      http://admisionunt.info/docs/padrones/20191/20...
# 11      http://admisionunt.info/docs/padrones/20191/20...
# 12      http://admisionunt.info/docs/padrones/20191/20...
# ...                                                   ...
# 139352  https://unitru.edu.pe/webfiles///Convocatoria/...
# 139353  https://unitru.edu.pe/webfiles///Convocatoria/...
# 139354  https://unitru.edu.pe/webfiles///Convocatoria/...
# 139355  https://unitru.edu.pe/webfiles///Convocatoria/...
# 139356  https://unitru.edu.pe/webfiles///Convocatoria/...
#
# [119027 rows x 16 columns]

# %% [markdown]
# # DELETE SOME GRADES

# %% [markdown]
# ## MAIN GRADES ARE FOUND IN R4 COLUMN

# %%
filter_by_cepunt = new_combined_data['test_type'] == 'cepunt'

# %%
filter_by_periodo = new_combined_data['year_period'].isin([2019, 2020])

# %%
main_grade4 = new_combined_data[(filter_by_cepunt) & (filter_by_periodo)]
main_grade4
# Out:
#                                       names     one     two    three     four  \
# 8      rodriguez sanchez rosicela elizabeth  41.577  78.261  126.368  246.206
# 9                llanos solis kimberlyn yei  37.504  67.242  109.044  213.790
# 10              alva perez tamara antonella  48.918  53.192  109.036  211.146
# 11                   uriol flores liz rocio  39.342  57.783  102.429  199.554
# 12                vasquez guerra cesar ivan  35.462  50.730  109.548  195.740
# ...                                     ...     ...     ...      ...      ...
# 37055              layza sanchez elvis alex   5.900   7.619    7.111   20.630
# 37056                infantes reyes jonatan   2.238   7.939    7.085   17.262
# 37057     sanchez fernandez samuel jhonatan   1.827  12.527    0.000   14.354
# 37058                    caipo polo hilario   5.900   0.000    0.000    5.900
# 37059         sandoval segura denni manfred  -0.826   0.295    0.000   -0.531
#
#          five          career      status  n_df        date test_type  \
# 8      94.842  administracion     ingresa     0  12/08/2018    cepunt
# 9      94.842  administracion     ingresa     0  12/08/2018    cepunt
# 10     94.842  administracion     ingresa     0  12/08/2018    cepunt
# 11     94.842  administracion     ingresa     0  12/08/2018    cepunt
# 12     94.842  administracion     ingresa     0  12/08/2018    cepunt
# ...       ...             ...         ...   ...         ...       ...
# 37055  44.190    ing de minas  no ingresa    37  09/02/2020    cepunt
# 37056  44.190    ing de minas  no ingresa    37  09/02/2020    cepunt
# 37057  44.190    ing de minas  no ingresa    37  09/02/2020    cepunt
# 37058  44.190    ing de minas  no ingresa    37  09/02/2020    cepunt
# 37059  44.190    ing de minas  no ingresa    37  09/02/2020    cepunt
#
#        year_period period  mod       place  \
# 8             2019      i  NaN    trujillo
# 9             2019      i  NaN    trujillo
# 10            2019      i  NaN    trujillo
# 11            2019      i  NaN    trujillo
# 12            2019      i  NaN    trujillo
# ...            ...    ...  ...         ...
# 37055         2020     ii  NaN  huamachuco
# 37056         2020     ii  NaN  huamachuco
# 37057         2020     ii  NaN  huamachuco
# 37058         2020     ii  NaN  huamachuco
# 37059         2020     ii  NaN  huamachuco
#
#                                                     link
# 8      http://admisionunt.info/docs/padrones/20191/20...
# 9      http://admisionunt.info/docs/padrones/20191/20...
# 10     http://admisionunt.info/docs/padrones/20191/20...
# 11     http://admisionunt.info/docs/padrones/20191/20...
# 12     http://admisionunt.info/docs/padrones/20191/20...
# ...                                                  ...
# 37055  http://admisionunt.info/docs/padrones/20202/20...
# 37056  http://admisionunt.info/docs/padrones/20202/20...
# 37057  http://admisionunt.info/docs/padrones/20202/20...
# 37058  http://admisionunt.info/docs/padrones/20202/20...
# 37059  http://admisionunt.info/docs/padrones/20202/20...
#
# [12292 rows x 16 columns]

# %%
# execute only one time
main_grade4 = main_grade4.drop(['one', 'two', 'three', 'five'], axis=1)

main_grade4 = main_grade4.rename(columns={'four': 'grade'})

main_grade4
# Out:
#                                       names    grade          career  \
# 8      rodriguez sanchez rosicela elizabeth  246.206  administracion
# 9                llanos solis kimberlyn yei  213.790  administracion
# 10              alva perez tamara antonella  211.146  administracion
# 11                   uriol flores liz rocio  199.554  administracion
# 12                vasquez guerra cesar ivan  195.740  administracion
# ...                                     ...      ...             ...
# 37055              layza sanchez elvis alex   20.630    ing de minas
# 37056                infantes reyes jonatan   17.262    ing de minas
# 37057     sanchez fernandez samuel jhonatan   14.354    ing de minas
# 37058                    caipo polo hilario    5.900    ing de minas
# 37059         sandoval segura denni manfred   -0.531    ing de minas
#
#            status  n_df        date test_type  year_period period  mod  \
# 8         ingresa     0  12/08/2018    cepunt         2019      i  NaN
# 9         ingresa     0  12/08/2018    cepunt         2019      i  NaN
# 10        ingresa     0  12/08/2018    cepunt         2019      i  NaN
# 11        ingresa     0  12/08/2018    cepunt         2019      i  NaN
# 12        ingresa     0  12/08/2018    cepunt         2019      i  NaN
# ...           ...   ...         ...       ...          ...    ...  ...
# 37055  no ingresa    37  09/02/2020    cepunt         2020     ii  NaN
# 37056  no ingresa    37  09/02/2020    cepunt         2020     ii  NaN
# 37057  no ingresa    37  09/02/2020    cepunt         2020     ii  NaN
# 37058  no ingresa    37  09/02/2020    cepunt         2020     ii  NaN
# 37059  no ingresa    37  09/02/2020    cepunt         2020     ii  NaN
#
#             place                                               link
# 8        trujillo  http://admisionunt.info/docs/padrones/20191/20...
# 9        trujillo  http://admisionunt.info/docs/padrones/20191/20...
# 10       trujillo  http://admisionunt.info/docs/padrones/20191/20...
# 11       trujillo  http://admisionunt.info/docs/padrones/20191/20...
# 12       trujillo  http://admisionunt.info/docs/padrones/20191/20...
# ...           ...                                                ...
# 37055  huamachuco  http://admisionunt.info/docs/padrones/20202/20...
# 37056  huamachuco  http://admisionunt.info/docs/padrones/20202/20...
# 37057  huamachuco  http://admisionunt.info/docs/padrones/20202/20...
# 37058  huamachuco  http://admisionunt.info/docs/padrones/20202/20...
# 37059  huamachuco  http://admisionunt.info/docs/padrones/20202/20...
#
# [12292 rows x 12 columns]

# %% [markdown]
# ## MAIN GRADES ARE FOUND IN R1 COLUMN

# %%
filter_by_tipo = new_combined_data['test_type'].isin(["extraordinario", "ordinario"])
filter_by_periodo2 = new_combined_data['year_period'] == 2024
filter_by_number2 = new_combined_data['period'] == "ii"

# %%
main_grade1 = new_combined_data[(filter_by_tipo) & (filter_by_periodo2) & (filter_by_number2)]

main_grade1
# Out:
#                                       names      one  two three four five  \
# 126006         castro garcia paulo gamaliel  147.835  NaN   NaN  NaN  NaN
# 126007           ponce salvador naomi belen  126.434  NaN   NaN  NaN  NaN
# 126008         pintado peña luciana nicolle  124.382  NaN   NaN  NaN  NaN
# 126009       lezama diaz jennifer anghelina  124.377  NaN   NaN  NaN  NaN
# 126010    abila villanueva adriana amparito  123.361  NaN   NaN  NaN  NaN
# ...                                     ...      ...  ...   ...  ...  ...
# 135172          castillo rojas hugo gabriel    4.044  NaN   NaN  NaN  NaN
# 135173           ruiz jacobo merly milagros    0.986  NaN   NaN  NaN  NaN
# 135174        ulloa flores manuel jhan fran   -0.100  NaN   NaN  NaN  NaN
# 135175  contreras gutierrez brayan mercedes   -4.159  NaN   NaN  NaN  NaN
# 135176          garcia coronel yohan esmith   -7.202  NaN   NaN  NaN  NaN
#
#                 career      status  n_df        date       test_type  \
# 126006  administracion     ingresa   192  03/03/2024  extraordinario
# 126007  administracion     ingresa   192  03/03/2024  extraordinario
# 126008  administracion     ingresa   192  03/03/2024  extraordinario
# 126009  administracion     ingresa   192  03/03/2024  extraordinario
# 126010  administracion     ingresa   192  03/03/2024  extraordinario
# ...                ...         ...   ...         ...             ...
# 135172   ing ambiental  no ingresa   205  17/03/2024       ordinario
# 135173   ing ambiental  no ingresa   205  17/03/2024       ordinario
# 135174   ing ambiental  no ingresa   205  17/03/2024       ordinario
# 135175   ing ambiental  no ingresa   205  17/03/2024       ordinario
# 135176   ing ambiental  no ingresa   205  17/03/2024       ordinario
#
#         year_period period  mod              place  \
# 126006         2024     ii  NaN           trujillo
# 126007         2024     ii  NaN           trujillo
# 126008         2024     ii  NaN           trujillo
# 126009         2024     ii  NaN           trujillo
# 126010         2024     ii  NaN           trujillo
# ...             ...    ...  ...                ...
# 135172         2024     ii  NaN  santiago de chuco
# 135173         2024     ii  NaN  santiago de chuco
# 135174         2024     ii  NaN  santiago de chuco
# 135175         2024     ii  NaN  santiago de chuco
# 135176         2024     ii  NaN  santiago de chuco
#
#                                                      link
# 126006  https://unitru.edu.pe/webfiles///Convocatoria/...
# 126007  https://unitru.edu.pe/webfiles///Convocatoria/...
# 126008  https://unitru.edu.pe/webfiles///Convocatoria/...
# 126009  https://unitru.edu.pe/webfiles///Convocatoria/...
# 126010  https://unitru.edu.pe/webfiles///Convocatoria/...
# ...                                                   ...
# 135172  https://unitru.edu.pe/webfiles///Convocatoria/...
# 135173  https://unitru.edu.pe/webfiles///Convocatoria/...
# 135174  https://unitru.edu.pe/webfiles///Convocatoria/...
# 135175  https://unitru.edu.pe/webfiles///Convocatoria/...
# 135176  https://unitru.edu.pe/webfiles///Convocatoria/...
#
# [7962 rows x 16 columns]

# %%
# execute only one time
main_grade1 = main_grade1.drop(['two', 'three', 'four', 'five'], axis=1)
main_grade1 = main_grade1.rename(columns={'one': 'grade'})

main_grade1
# Out:
#                                       names    grade          career  \
# 126006         castro garcia paulo gamaliel  147.835  administracion
# 126007           ponce salvador naomi belen  126.434  administracion
# 126008         pintado peña luciana nicolle  124.382  administracion
# 126009       lezama diaz jennifer anghelina  124.377  administracion
# 126010    abila villanueva adriana amparito  123.361  administracion
# ...                                     ...      ...             ...
# 135172          castillo rojas hugo gabriel    4.044   ing ambiental
# 135173           ruiz jacobo merly milagros    0.986   ing ambiental
# 135174        ulloa flores manuel jhan fran   -0.100   ing ambiental
# 135175  contreras gutierrez brayan mercedes   -4.159   ing ambiental
# 135176          garcia coronel yohan esmith   -7.202   ing ambiental
#
#             status  n_df        date       test_type  year_period period  mod  \
# 126006     ingresa   192  03/03/2024  extraordinario         2024     ii  NaN
# 126007     ingresa   192  03/03/2024  extraordinario         2024     ii  NaN
# 126008     ingresa   192  03/03/2024  extraordinario         2024     ii  NaN
# 126009     ingresa   192  03/03/2024  extraordinario         2024     ii  NaN
# 126010     ingresa   192  03/03/2024  extraordinario         2024     ii  NaN
# ...            ...   ...         ...             ...          ...    ...  ...
# 135172  no ingresa   205  17/03/2024       ordinario         2024     ii  NaN
# 135173  no ingresa   205  17/03/2024       ordinario         2024     ii  NaN
# 135174  no ingresa   205  17/03/2024       ordinario         2024     ii  NaN
# 135175  no ingresa   205  17/03/2024       ordinario         2024     ii  NaN
# 135176  no ingresa   205  17/03/2024       ordinario         2024     ii  NaN
#
#                     place                                               link
# 126006           trujillo  https://unitru.edu.pe/webfiles///Convocatoria/...
# 126007           trujillo  https://unitru.edu.pe/webfiles///Convocatoria/...
# 126008           trujillo  https://unitru.edu.pe/webfiles///Convocatoria/...
# 126009           trujillo  https://unitru.edu.pe/webfiles///Convocatoria/...
# 126010           trujillo  https://unitru.edu.pe/webfiles///Convocatoria/...
# ...                   ...                                                ...
# 135172  santiago de chuco  https://unitru.edu.pe/webfiles///Convocatoria/...
# 135173  santiago de chuco  https://unitru.edu.pe/webfiles///Convocatoria/...
# 135174  santiago de chuco  https://unitru.edu.pe/webfiles///Convocatoria/...
# 135175  santiago de chuco  https://unitru.edu.pe/webfiles///Convocatoria/...
# 135176  santiago de chuco  https://unitru.edu.pe/webfiles///Convocatoria/...
#
# [7962 rows x 12 columns]

# %% [markdown]
# ## MAIN GRADES ARE FOUND IN R3 COLUMN

# %%
filter_general = (((filter_by_cepunt) & (filter_by_periodo)) | ((filter_by_tipo) & (filter_by_periodo2) & (filter_by_number2))) 

main_grade3 = new_combined_data[~filter_general]

# %%
# execute only one time
main_grade3 = main_grade3.drop(['one', 'two', 'four', 'five'], axis=1)
main_grade3 = main_grade3.rename(columns={'three': 'grade'})
main_grade3
# Out:
#                                     names    grade           career  \
# 3840           marcelo soto dilmer oliver  190.591  ccas biologicas
# 3841    arevalo ramirez dulcemaria janina  136.534  ccas biologicas
# 3842    rodriguez seminario carmen emilia  115.111  ccas biologicas
# 3843     rodriguez pesantes daiana lisett  115.080  ccas biologicas
# 3844       dioses ibañez guillermo franco  107.995  ccas biologicas
# ...                                   ...      ...              ...
# 139352      bravo lezama dariks alexander   43.168     ing de minas
# 139353     otiniano sanchez helen neftali   40.160     ing de minas
# 139354               perez joaquin marcos   36.449     ing de minas
# 139355            amador avila luis mario   31.170     ing de minas
# 139356       castillo liñan clever felipe   19.567     ing de minas
#
#             status  n_df        date  test_type  year_period period  mod  \
# 3840       ingresa     3  22/09/2018  ordinario         2019      i  NaN
# 3841       ingresa     3  22/09/2018  ordinario         2019      i  NaN
# 3842       ingresa     3  22/09/2018  ordinario         2019      i  NaN
# 3843       ingresa     3  22/09/2018  ordinario         2019      i  NaN
# 3844       ingresa     3  22/09/2018  ordinario         2019      i  NaN
# ...            ...   ...         ...        ...          ...    ...  ...
# 139352  no ingresa   208  21/07/2024     cepunt         2025      i  NaN
# 139353  no ingresa   208  21/07/2024     cepunt         2025      i  NaN
# 139354  no ingresa   208  21/07/2024     cepunt         2025      i  NaN
# 139355  no ingresa   208  21/07/2024     cepunt         2025      i  NaN
# 139356  no ingresa   208  21/07/2024     cepunt         2025      i  NaN
#
#              place                                               link
# 3840      trujillo  http://admisionunt.info/docs/padrones/20191/20...
# 3841      trujillo  http://admisionunt.info/docs/padrones/20191/20...
# 3842      trujillo  http://admisionunt.info/docs/padrones/20191/20...
# 3843      trujillo  http://admisionunt.info/docs/padrones/20191/20...
# 3844      trujillo  http://admisionunt.info/docs/padrones/20191/20...
# ...            ...                                                ...
# 139352  huamachuco  https://unitru.edu.pe/webfiles///Convocatoria/...
# 139353  huamachuco  https://unitru.edu.pe/webfiles///Convocatoria/...
# 139354  huamachuco  https://unitru.edu.pe/webfiles///Convocatoria/...
# 139355  huamachuco  https://unitru.edu.pe/webfiles///Convocatoria/...
# 139356  huamachuco  https://unitru.edu.pe/webfiles///Convocatoria/...
#
# [98773 rows x 12 columns]

# %% [markdown]
# ## CONCAT GRADES

# %%
cleaned_results = pd.concat(
    [
        main_grade1,
        main_grade3,
        main_grade4
    ]
)
cleaned_results
# Out:
#                                     names    grade          career  \
# 126006       castro garcia paulo gamaliel  147.835  administracion
# 126007         ponce salvador naomi belen  126.434  administracion
# 126008       pintado peña luciana nicolle  124.382  administracion
# 126009     lezama diaz jennifer anghelina  124.377  administracion
# 126010  abila villanueva adriana amparito  123.361  administracion
# ...                                   ...      ...             ...
# 37055            layza sanchez elvis alex   20.630    ing de minas
# 37056              infantes reyes jonatan   17.262    ing de minas
# 37057   sanchez fernandez samuel jhonatan   14.354    ing de minas
# 37058                  caipo polo hilario    5.900    ing de minas
# 37059       sandoval segura denni manfred   -0.531    ing de minas
#
#             status  n_df        date       test_type  year_period period  mod  \
# 126006     ingresa   192  03/03/2024  extraordinario         2024     ii  NaN
# 126007     ingresa   192  03/03/2024  extraordinario         2024     ii  NaN
# 126008     ingresa   192  03/03/2024  extraordinario         2024     ii  NaN
# 126009     ingresa   192  03/03/2024  extraordinario         2024     ii  NaN
# 126010     ingresa   192  03/03/2024  extraordinario         2024     ii  NaN
# ...            ...   ...         ...             ...          ...    ...  ...
# 37055   no ingresa    37  09/02/2020          cepunt         2020     ii  NaN
# 37056   no ingresa    37  09/02/2020          cepunt         2020     ii  NaN
# 37057   no ingresa    37  09/02/2020          cepunt         2020     ii  NaN
# 37058   no ingresa    37  09/02/2020          cepunt         2020     ii  NaN
# 37059   no ingresa    37  09/02/2020          cepunt         2020     ii  NaN
#
#              place                                               link
# 126006    trujillo  https://unitru.edu.pe/webfiles///Convocatoria/...
# 126007    trujillo  https://unitru.edu.pe/webfiles///Convocatoria/...
# 126008    trujillo  https://unitru.edu.pe/webfiles///Convocatoria/...
# 126009    trujillo  https://unitru.edu.pe/webfiles///Convocatoria/...
# 126010    trujillo  https://unitru.edu.pe/webfiles///Convocatoria/...
# ...            ...                                                ...
# 37055   huamachuco  http://admisionunt.info/docs/padrones/20202/20...
# 37056   huamachuco  http://admisionunt.info/docs/padrones/20202/20...
# 37057   huamachuco  http://admisionunt.info/docs/padrones/20202/20...
# 37058   huamachuco  http://admisionunt.info/docs/padrones/20202/20...
# 37059   huamachuco  http://admisionunt.info/docs/padrones/20202/20...
#
# [119027 rows x 12 columns]

# %%
cleaned_results = cleaned_results.reset_index()
cleaned_results = cleaned_results.drop(['index', 'n_df'], axis=1)
cleaned_results
# Out:
#                                     names    grade          career  \
# 0            castro garcia paulo gamaliel  147.835  administracion
# 1              ponce salvador naomi belen  126.434  administracion
# 2            pintado peña luciana nicolle  124.382  administracion
# 3          lezama diaz jennifer anghelina  124.377  administracion
# 4       abila villanueva adriana amparito  123.361  administracion
# ...                                   ...      ...             ...
# 119022           layza sanchez elvis alex   20.630    ing de minas
# 119023             infantes reyes jonatan   17.262    ing de minas
# 119024  sanchez fernandez samuel jhonatan   14.354    ing de minas
# 119025                 caipo polo hilario    5.900    ing de minas
# 119026      sandoval segura denni manfred   -0.531    ing de minas
#
#             status        date       test_type  year_period period  mod  \
# 0          ingresa  03/03/2024  extraordinario         2024     ii  NaN
# 1          ingresa  03/03/2024  extraordinario         2024     ii  NaN
# 2          ingresa  03/03/2024  extraordinario         2024     ii  NaN
# 3          ingresa  03/03/2024  extraordinario         2024     ii  NaN
# 4          ingresa  03/03/2024  extraordinario         2024     ii  NaN
# ...            ...         ...             ...          ...    ...  ...
# 119022  no ingresa  09/02/2020          cepunt         2020     ii  NaN
# 119023  no ingresa  09/02/2020          cepunt         2020     ii  NaN
# 119024  no ingresa  09/02/2020          cepunt         2020     ii  NaN
# 119025  no ingresa  09/02/2020          cepunt         2020     ii  NaN
# 119026  no ingresa  09/02/2020          cepunt         2020     ii  NaN
#
#              place                                               link
# 0         trujillo  https://unitru.edu.pe/webfiles///Convocatoria/...
# 1         trujillo  https://unitru.edu.pe/webfiles///Convocatoria/...
# 2         trujillo  https://unitru.edu.pe/webfiles///Convocatoria/...
# 3         trujillo  https://unitru.edu.pe/webfiles///Convocatoria/...
# 4         trujillo  https://unitru.edu.pe/webfiles///Convocatoria/...
# ...            ...                                                ...
# 119022  huamachuco  http://admisionunt.info/docs/padrones/20202/20...
# 119023  huamachuco  http://admisionunt.info/docs/padrones/20202/20...
# 119024  huamachuco  http://admisionunt.info/docs/padrones/20202/20...
# 119025  huamachuco  http://admisionunt.info/docs/padrones/20202/20...
# 119026  huamachuco  http://admisionunt.info/docs/padrones/20202/20...
#
# [119027 rows x 11 columns]

# %%
filter_extraor_lugar_nan = (
        (cleaned_results['test_type'] == 'extraordinario') & 
        (cleaned_results['place'].isna())
        )
    
filter_extraor_mod_nan = (
    (cleaned_results['test_type'] == 'extraordinario') & 
    (cleaned_results['mod'].isna())
    )
    
filter_ordi_mod_nan = (
    (cleaned_results['test_type'] == 'ordinario') & 
    (cleaned_results['mod'].isna())
    )
    
filter_cepu_mod_nan = (
    (cleaned_results['test_type'] == 'cepunt') & 
    (cleaned_results['mod'].isna())
    )
    
cleaned_results.loc[filter_extraor_lugar_nan, 'place'] = "trujillo"
cleaned_results.loc[filter_extraor_mod_nan, 'mod'] = "excelencia"
cleaned_results.loc[filter_ordi_mod_nan, 'mod'] = "estandar"
cleaned_results.loc[filter_cepu_mod_nan, 'mod'] = "estandar"

# %%
cleaned_results['mod'].value_counts()
# Out:
# mod
# estandar                     104747
# 5to secundaria                 8709
# excelencia                     5438
# personas con discapacidad       104
# victimas de la violencia         24
# deportistas calificados           5
# Name: count, dtype: int64

# %%
cleaned_results['grade'].isna().sum()
# Out:
# 0
