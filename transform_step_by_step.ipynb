# %%
import numpy as np
import pandas as pd
import re

# %% [markdown]
# # GET RAW DATA

# %%
df = pd.read_csv('./get_data/raw_data.csv')
df
# Out:
#                                                      main  n_df
# 0                                        CENTRO DE EST...     0
# 1        DIREC.DE SIST.y COMUNICACIONES               ...     0
# 2                   * UNIDAD P.A.D.*                  ...     0
# 3                                      RESULTADOS GENE...     0
# 4        =============================================...     0
# ...                                                   ...   ...
# 135174    0013 060469  POLO REYES JULIO MARTIN        ...   205
# 135175    0014 108769  ALFARO MEDRANO MARIA JOSE      ...   205
# 135176    0015 068169  JESUS VEGA CRISTIAN JOEL       ...   205
# 135177    ********************************************...   205
# 135178        Nro TOTAL DE POSTULANTES =====>         ...   205
#
# [135179 rows x 2 columns]

# %% [markdown]
# ## DELETE AND REPLACE WHITE SPACES

# %%
many_white_spaces = re.compile(r'\s+')
one_white_space = ' '

df['main'] = (
    df['main']
    .str.replace(many_white_spaces, one_white_space, regex=True)
    .str.strip()
)
df
# Out:
#                                                      main  n_df
# 0       CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     0
# 1       DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...     0
# 2              * UNIDAD P.A.D.* << TRUJILLO >> 12/08/2018     0
# 3       RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...     0
# 4       ==============================================...     0
# ...                                                   ...   ...
# 135174  0013 060469 POLO REYES JULIO MARTIN 14.262 24....   205
# 135175  0014 108769 ALFARO MEDRANO MARIA JOSE 18.346 1...   205
# 135176  0015 068169 JESUS VEGA CRISTIAN JOEL -0.422 25...   205
# 135177  **********************************************...   205
# 135178               Nro TOTAL DE POSTULANTES =====> 3368   205
#
# [135179 rows x 2 columns]

# %% [markdown]
# # ONLY RESULTS

# %%
# results_first_character = '0'
fourt_digits = re.compile(r'^\d{4}')

filter_by_character = (
    df['main']
    # .str.startswith(results_first_character)
    .str.contains(fourt_digits, regex=True)
)

raw_results_df = df[filter_by_character]
raw_results_df
# Out:
#                                                      main  n_df
# 8       0001 171558 RODRIGUEZ SANCHEZ ROSICELA ELIZABE...     0
# 9       0002 061758 LLANOS SOLIS KIMBERLYN YEI 37.504 ...     0
# 10      0003 178758 ALVA PEREZ TAMARA ANTONELLA 48.918...     0
# 11      0004 028758 URIOL FLORES LIZ ROCIO 39.342 57.7...     0
# 12      0005 170858 VASQUEZ GUERRA CESAR IVAN 35.462 5...     0
# ...                                                   ...   ...
# 135172  0011 065269 LAZARO LLANOS RICHARD JOEL 31.799 ...   205
# 135173  0012 147969 ALBUJAR VIERA LUIS ALBERTO 28.948 ...   205
# 135174  0013 060469 POLO REYES JULIO MARTIN 14.262 24....   205
# 135175  0014 108769 ALFARO MEDRANO MARIA JOSE 18.346 1...   205
# 135176  0015 068169 JESUS VEGA CRISTIAN JOEL -0.422 25...   205
#
# [115385 rows x 2 columns]

# %% [markdown]
# # CABECERAS

# %%
titles_df = df[~filter_by_character]
titles_df
# Out:
#                                                      main  n_df
# 0       CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     0
# 1       DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...     0
# 2              * UNIDAD P.A.D.* << TRUJILLO >> 12/08/2018     0
# 3       RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...     0
# 4       ==============================================...     0
# ...                                                   ...   ...
# 135154                                   OR- I II PUNTAJE   205
# 135155  DEN CARNET APELIIDOS y NOMBRES SUMATIVO SUMATI...   205
# 135156  ==============================================...   205
# 135177  **********************************************...   205
# 135178               Nro TOTAL DE POSTULANTES =====> 3368   205
#
# [19794 rows x 2 columns]

# %%
pag_number = re.compile(r'Pag\.\s\d+')
empty_string = ''

titles_df.loc[:, 'main'] = (
    titles_df['main']
    .str.replace(pag_number, empty_string, regex=True)
    .str.rstrip()
    )

titles_df
# Out:
#                                                      main  n_df
# 0       CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     0
# 1       DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...     0
# 2              * UNIDAD P.A.D.* << TRUJILLO >> 12/08/2018     0
# 3       RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...     0
# 4       ==============================================...     0
# ...                                                   ...   ...
# 135154                                   OR- I II PUNTAJE   205
# 135155  DEN CARNET APELIIDOS y NOMBRES SUMATIVO SUMATI...   205
# 135156  ==============================================...   205
# 135177  **********************************************...   205
# 135178               Nro TOTAL DE POSTULANTES =====> 3368   205
#
# [19794 rows x 2 columns]

# %%
titles_sep_sign = "="

def filter_group(dataframe_group):

    filter_title = (
        dataframe_group
        ['main']
        .str.startswith(titles_sep_sign)
    )

    index_value = (
        dataframe_group
        [filter_title]
        .index
        [0]
    )

    return dataframe_group.loc[:index_value]

titles_group_by_n_df = (
    titles_df
    .drop_duplicates(['main', 'n_df'])
    .groupby('n_df')
)

# %%
filtered_titles = map(lambda values: filter_group(values[1]), titles_group_by_n_df)
raw_titles_df = pd.concat(filtered_titles)
raw_titles_df # .head(40)

raw_titles_df
# Out:
#                                                      main  n_df
# 0       CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     0
# 1       DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...     0
# 2              * UNIDAD P.A.D.* << TRUJILLO >> 12/08/2018     0
# 3       RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...     0
# 4       ==============================================...     0
# ...                                                   ...   ...
# 131038  ==============================================...   204
# 131326  OFICINA DE TECNOLOGIAS DE LA INFORMACION DE LA...   205
# 131327  18/02/2024 EXAMENES SUMATIVOS 2024-II - CEPUNT II   205
# 131328  RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...   205
# 131329  ==============================================...   205
#
# [927 rows x 2 columns]

# %%
filter_sign_equal = (
    raw_titles_df
    ['main']
    .str.startswith(titles_sep_sign)
)

raw_titles_df = (
    raw_titles_df
    [~filter_sign_equal]
)

raw_titles_df
# Out:
#                                                      main  n_df
# 0       CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     0
# 1       DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...     0
# 2              * UNIDAD P.A.D.* << TRUJILLO >> 12/08/2018     0
# 3       RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...     0
# 3370    CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     1
# ...                                                   ...   ...
# 131036  18/02/2024 EXAMENES SUMATIVOS 2024-II - CEPUNT II   204
# 131037  RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...   204
# 131326  OFICINA DE TECNOLOGIAS DE LA INFORMACION DE LA...   205
# 131327  18/02/2024 EXAMENES SUMATIVOS 2024-II - CEPUNT II   205
# 131328  RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...   205
#
# [721 rows x 2 columns]

# %%
n_rows_titles = raw_titles_df.groupby("n_df").count()
n_rows_titles
# Out:
#       main
# n_df
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
# ...    ...
# 201      4
# 202      4
# 203      3
# 204      3
# 205      3
#
# [206 rows x 1 columns]

# %%
raw_titles_df = pd.merge(raw_titles_df, n_rows_titles, left_on='n_df', right_on='n_df')
raw_titles_df
# Out:
#                                                 main_x  n_df  main_y
# 0    CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     0       4
# 1    DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...     0       4
# 2           * UNIDAD P.A.D.* << TRUJILLO >> 12/08/2018     0       4
# 3    RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...     0       4
# 4    CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     1       4
# ..                                                 ...   ...     ...
# 716  18/02/2024 EXAMENES SUMATIVOS 2024-II - CEPUNT II   204       3
# 717  RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...   204       3
# 718  OFICINA DE TECNOLOGIAS DE LA INFORMACION DE LA...   205       3
# 719  18/02/2024 EXAMENES SUMATIVOS 2024-II - CEPUNT II   205       3
# 720  RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...   205       3
#
# [721 rows x 3 columns]

# %%
def add_serie(df):
    max_value = df['main_y'].max()
    df['aux'] = range(max_value)
    return df

# %%
aux_df = map(lambda values: add_serie(values[1]), raw_titles_df.groupby("n_df"))
raw_titles_df = pd.concat(aux_df)
raw_titles_df
# Out:
#                                                 main_x  n_df  main_y  aux
# 0    CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     0       4    0
# 1    DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...     0       4    1
# 2           * UNIDAD P.A.D.* << TRUJILLO >> 12/08/2018     0       4    2
# 3    RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...     0       4    3
# 4    CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...     1       4    0
# ..                                                 ...   ...     ...  ...
# 716  18/02/2024 EXAMENES SUMATIVOS 2024-II - CEPUNT II   204       3    1
# 717  RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...   204       3    2
# 718  OFICINA DE TECNOLOGIAS DE LA INFORMACION DE LA...   205       3    0
# 719  18/02/2024 EXAMENES SUMATIVOS 2024-II - CEPUNT II   205       3    1
# 720  RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...   205       3    2
#
# [721 rows x 4 columns]

# %%
# number_of_first_row = 0
# filter_rows_by_aux = raw_titles_df['aux'] != number_of_first_row

# raw_titles_df = raw_titles_df[filter_rows_by_aux]
# raw_titles_df

# %%
# raw_titles_df.loc[:, ['n_df', 'aux', 'main_x']].set_index(['n_df', 'aux']).unstack()
unstacked_titles = (
    raw_titles_df
    .loc[:, ['n_df', 'aux', 'main_x']]
    .set_index(['n_df', 'aux'])
    .unstack()
    .droplevel(['aux'], axis=1)
)
unstacked_titles.columns = ['first', 'second', 'third', 'fourth']
unstacked_titles
# Out:
#                                                   first  \
# n_df
# 0     CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...
# 1     CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...
# 2     CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...
# 3                UNIVERSIDAD NACIONAL DE TRUJILLO - UNT
# 4                UNIVERSIDAD NACIONAL DE TRUJILLO - UNT
# ...                                                 ...
# 201   CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...
# 202   CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT...
# 203   OFICINA DE TECNOLOGIAS DE LA INFORMACION DE LA...
# 204   OFICINA DE TECNOLOGIAS DE LA INFORMACION DE LA...
# 205   OFICINA DE TECNOLOGIAS DE LA INFORMACION DE LA...
#
#                                                  second  \
# n_df
# 0     DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...
# 1     DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...
# 2     DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATI...
# 3     DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION OR...
# 4     DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION OR...
# ...                                                 ...
# 201   OFI.DE TECNOLOG.DE LA INFORMAC. EXAMENES SUMAT...
# 202   OFI.DE TECNOLOG.DE LA INFORMAC. EXAMENES SUMAT...
# 203   18/02/2024 EXAMENES SUMATIVOS 2024-II - CEPUNT II
# 204   18/02/2024 EXAMENES SUMATIVOS 2024-II - CEPUNT II
# 205   18/02/2024 EXAMENES SUMATIVOS 2024-II - CEPUNT II
#
#                                                   third  \
# n_df
# 0            * UNIDAD P.A.D.* << TRUJILLO >> 12/08/2018
# 1        * UNIDAD P.A.D.* << JEQUETEPEQUE >> 12/08/2018
# 2          * UNIDAD P.A.D.* << HUAMACHUCO >> 12/08/2018
# 3                 * UNIDAD P.A.D.* GRUPO : A 22/09/2018
# 4                 * UNIDAD P.A.D.* GRUPO : B 23/09/2018
# ...                                                 ...
# 201           * AREA P.A.D.* << V A L L E >> 20/08/2023
# 202          * AREA P.A.D.* << HUAMACHUCO >> 20/08/2023
# 203   RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...
# 204   RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...
# 205   RESULTADOS GENERALES POR ESCUELA PROFESIONAL *...
#
#                                                  fourth
# n_df
# 0     RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...
# 1     RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...
# 2     RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...
# 3          RESULTADOS GENERALES POR ESCUELA PROFESIONAL
# 4          RESULTADOS GENERALES POR ESCUELA PROFESIONAL
# ...                                                 ...
# 201   RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...
# 202   RESULTADOS GENERALES - ORDEN DE MERITO POR ESC...
# 203                                                 NaN
# 204                                                 NaN
# 205                                                 NaN
#
# [206 rows x 4 columns]

# %% [markdown]
# # FIRST COLUMN

# %%
unstacked_titles['first'].value_counts()
# Out:
# first
# UNIVERSIDAD NACIONAL DE TRUJILLO - UNT                                                   174
# OFICINA DE TECNOLOGIAS DE LA INFORMACION DE LA UNIVERSIDAD NACIONAL DE TRUJILLO - UNT     17
# CENTRO DE ESTUDIOS PREUNIVERSITARIOS DE LA UNT - CEPUNT                                   15
# Name: count, dtype: int64

# %% [markdown]
# ## FIRST COLUMN TESTS

# %%
ends_with = re.compile(r'(CEPUNT|UNT)$')

first_test = (
    unstacked_titles
    ['first']
    .str.extract(ends_with)
    [0]
    # .value_counts()
    # .sum()
)

first_test
# Out:
# n_df
# 0      CEPUNT
# 1      CEPUNT
# 2      CEPUNT
# 3         UNT
# 4         UNT
#         ...
# 201    CEPUNT
# 202    CEPUNT
# 203       UNT
# 204       UNT
# 205       UNT
# Name: 0, Length: 206, dtype: object

# %% [markdown]
# # SECOND COLUMN

# %%
unstacked_titles['second'].value_counts().sort_index(ascending=False).head(49)
# Out:
# second
# OFI.DE TECNOLOG.DE LA INFORMAC. EXAMENES SUMATIVOS 2024- I - CEPUNT I                 3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2024-I                       3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2024- I - TRUJILLO           3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2023-II - V A L L E          3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2023-II - TRUJILLO           3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2023-II - STGO.DE CHUCO      1
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2023-II - HUAMACHUCO         3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2023-I                       3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2023- I - TRUJILLO           3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2022-II - V A L L E          3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2022-II - TRUJILLO           3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2022-II - STGO.DE CHUCO      1
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2022-II - HUAMACHUCO         3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2022-I                       3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION ORDINARIO 2022- I - TRUJILLO           3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2024- I * TRUJILLO      2
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2023-II * V A L L E     2
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2023-II * TRUJILLO      3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2023-II * HUAMACHUCO    1
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2023- I * TRUJILLO      2
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2022-II * V A L L E     1
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2022-II * TRUJILLO      4
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2022-II * HUAMACHUCO    1
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION EXTRAORDINARIO 2022- I * TRUJILLO      2
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2023-II - CEPUNT II * V A L L E        3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2023-II - CEPUNT II * TRUJILLO         3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2023-II - CEPUNT II * HUAMACHUCO       3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2023- I - CEPUNT I * V A L L E         3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2023- I - CEPUNT I * TRUJILLO          3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2023- I - CEPUNT I * HUAMACHUCO        3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2022-II - CEPUNT II * V A L L E        3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2022-II - CEPUNT II * TRUJILLO         3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2022-II - CEPUNT II * HUAMACHUCO       3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2022- I - CEPUNT I * V A L L E         3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2022- I - CEPUNT I * TRUJILLO          3
# OF.DE TECNOLOG.DE LA INFOR. EXAMEN DE ADMISION 2022- I - CEPUNT I * HUAMACHUCO        3
# DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATIVOS 2020-II - CEPUNT II                 3
# DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATIVOS 2020- I - CEPUNT I                  3
# DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATIVOS 2019-II - CEPUNT II                 3
# DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATIVOS 2019- I - CEPUNT I                  3
# DIREC.DE SIST.y COMUNICAC. EXAMEN DE ADMISION ORDINARIO 2021-II * STGO.DE CHUCO       1
# DIREC.DE SIST.y COMUNICAC. EXAMEN DE ADMISION ORDINARIO 2020-II * STGO.DE CHUCO       1
# DIREC.DE SIST.y COMUNICAC. EXAMEN DE ADMISION ORDINARIO 2019-II * STGO.DE CHUCO       1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021-II - TRUJILLO              3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021-II * JEQUETEPEQUE          3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021- I - TRUJILLO              4
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021- I * TRUJILLO              4
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2020-II - TRUJILLO              2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2020-II * JEQUETEPEQUE          2
# Name: count, dtype: int64

# %%
unstacked_titles['second'].value_counts().sort_index(ascending=False).tail(50)
# Out:
# second
# DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATIVOS 2019-II - CEPUNT II                 3
# DIREC.DE SIST.y COMUNICACIONES EXAMENES SUMATIVOS 2019- I - CEPUNT I                  3
# DIREC.DE SIST.y COMUNICAC. EXAMEN DE ADMISION ORDINARIO 2021-II * STGO.DE CHUCO       1
# DIREC.DE SIST.y COMUNICAC. EXAMEN DE ADMISION ORDINARIO 2020-II * STGO.DE CHUCO       1
# DIREC.DE SIST.y COMUNICAC. EXAMEN DE ADMISION ORDINARIO 2019-II * STGO.DE CHUCO       1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021-II - TRUJILLO              3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021-II * JEQUETEPEQUE          3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021- I - TRUJILLO              4
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021- I * TRUJILLO              4
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2020-II - TRUJILLO              2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2020-II * JEQUETEPEQUE          2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2020- I - TRUJILLO              2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2020- I * TRUJILLO              2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2019-II - TRUJILLO              2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2019-II * JEQUETEPEQUE          2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2019- I - TRUJILLO              2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2019- I * TRUJILLO              2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2021-II * TRUJILLO         1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2021-II * HUAMACHUCO       1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2021- I * TRUJILLO         1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2020-II * TRUJILLO         1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2020-II * STGO.DE CHUCO    1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2020-II * HUAMACHUCO       1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2020- I * TRUJILLO         1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2019-II * TRUJILLO         1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2019-II * STGO.DE CHUCO    1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2019-II * HUAMACHUCO       1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2019- I * TRUJILLO         1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2021-II - CEPUNT II * TRUJILLO            3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2021-II - CEPUNT II * HUAMACHUCO          3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2021-II * TRUJILLO                        2
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2021- I - CEPUNT I * TRUJILLO             3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2021- I - CEPUNT I * HUAMACHUCO           3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2020-II * TRUJILLO                        3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2020- I * TRUJILLO                        1
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2019-II * TRUJILLO                        3
# DIREC.DE SIST.y COMUNIC. EXAMEN DE ADMISION 2019- I * TRUJILLO                        1
# DIREC.DE SIS.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2021-II * JEQUETEPEQUE      1
# DIREC.DE SIS.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2020-II * JEQUETEPEQUE      1
# DIREC.DE SIS.y COMUNIC. EXAMEN DE ADMISION EXTRAORDINARIO 2019-II * JEQUETEPEQUE      1
# DIREC.DE SIS.y COMUNIC. EXAMEN DE ADMISION 2021-II - CEPUNT II * JEQUETEPEQUE         3
# DIREC.DE SIS.y COMUNIC. EXAMEN DE ADMISION 2021- I - CEPUNT I * JEQUETEPEQUE          3
# DIR.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2021-II * HUAMACHUCO              3
# DIR.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2020-II * HUAMACHUCO              2
# DIR.DE SIST.y COMUNIC. EXAMEN DE ADMISION ORDINARIO 2019-II * HUAMACHUCO              2
# 18/02/2024 EXAMENES SUMATIVOS 2024-II - CEPUNT II                                     3
# 17/03/2024 EXAMEN DE ADMISION ORDINARIO 2024-II                                       4
# 16/03/2024 EXAMEN DE ADMISION ORDINARIO 2024-II                                       3
# 03/03/2024 EXAMEN DE ADMISION EXTRAORDINARIO 2024-II * TRUJILLO                       3
# 03/03/2024 EXAMEN DE ADMISION EXTRAORDINARIO 2024-II                                  4
# Name: count, dtype: int64

# %%
# places = {
#     'TRUJILLO': 'TRUJILLO',
#     'HUAMACHUCO': 'HUAMACHUCO',
#     'JEQUETEPEQUE': 'JEQUETEPEQUE',
#     'STGOCHUCO': 'STGO.DE CHUCO',
#     'VALLE': 'V A L L E'
# }

# date_format = '\d\d/\d\d/\d\d\d\d'
# places = 'STGO\.DE CHUCO|TRUJILLO|HUAMACHUCO|JEQUETEPEQUE|V A L L E'
# type_tests = 'ORDINARIO|CEPUNT|EXTRAORDINARIO'
# type_users = 'DISCAPACITADOS|DEPORTISTAS CALIFICADOS|VICT.+DE LA VIOLENCIA|QUINTO GRADO DE EDUCACION SECUNDARIA'

# unstacked_titles['second'].str.extractall(f"({date_format}|{type_tests}|{places}|{type_users})").unstack().tail(50)

# %% [markdown]
# ## SECOND COLUMN DATES

# %%
valid_date = re.compile(r'(\d\d/\d\d/\d+)')

second_date = (
    unstacked_titles
    ['second']
    .str.extract(valid_date)
    [0]
    # .value_counts()
    # .sum()
)

second_date
# Out:
# n_df
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 201           NaN
# 202           NaN
# 203    18/02/2024
# 204    18/02/2024
# 205    18/02/2024
# Name: 0, Length: 206, dtype: object

# %% [markdown]
# ## SECOND COLUMN PLACES

# %%
valid_places = re.compile(r'(STGO.+DE CHUCO|TRUJILLO|HUAMACHUCO|JEQUETEPEQUE|V A L L E)')

second_places = (
    unstacked_titles
    ['second']
    .str.extract(valid_places)
    [0]
    .str.replace('V A L L E', 'VALLE', regex=False)
    # .value_counts()
    # .sum()
)

second_places.value_counts()
# Out:
# 0
# TRUJILLO         88
# HUAMACHUCO       36
# VALLE            21
# JEQUETEPEQUE     16
# STGO.DE CHUCO     7
# Name: count, dtype: int64

# %% [markdown]
# ## SECOND COLUMN TESTS

# %%
valid_tests = re.compile(r'(ORDINARIO|CEPUNT|EXTRAORDINARIO)')

second_tests = (
    unstacked_titles
    ['second']
    .str.extract(valid_tests)
    [0]
    # .value_counts()
    # .sum()
)

second_tests
# Out:
# n_df
# 0         CEPUNT
# 1         CEPUNT
# 2         CEPUNT
# 3      ORDINARIO
# 4      ORDINARIO
#          ...
# 201       CEPUNT
# 202       CEPUNT
# 203       CEPUNT
# 204       CEPUNT
# 205       CEPUNT
# Name: 0, Length: 206, dtype: object

# %% [markdown]
# ## SECOND COLUMN USERS

# %%
valid_users = re.compile(r'(DISCAPACITADOS|DEPORTISTAS CALIFICADOS|VICT.+DE LA VIOLENCIA|QUINTO GRADO DE EDUCACION SECUNDARIA)')

second_users = (
    unstacked_titles
    ['second']
    .str.extract(valid_users)
    [0]
    # .value_counts()
    # .sum()
)

second_users.value_counts()

# no hay users
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# # THIRD COLUMN

# %%
unstacked_titles['third'].value_counts().sort_index().head(60)
# Out:
# third
# * AREA P.A.D.* << HUAMACHUCO >> 20/08/2023                                                           1
# * AREA P.A.D.* << TRUJILLO >> 20/08/2023                                                             1
# * AREA P.A.D.* << V A L L E >> 20/08/2023                                                            1
# * AREA P.A.D.* AREA * A 30/09/2023                                                                   1
# * AREA P.A.D.* AREA - D 23/09/2023                                                                   1
# * AREA P.A.D.* AREA : A 07/04/2022                                                                   3
# * AREA P.A.D.* AREA : A 21/10/2022                                                                   1
# * AREA P.A.D.* AREA : A 24/03/2023                                                                   3
# * AREA P.A.D.* AREA : A 28/10/2021                                                                   1
# * AREA P.A.D.* AREA : B 08/04/2022                                                                   4
# * AREA P.A.D.* AREA : B 22/10/2022                                                                   1
# * AREA P.A.D.* AREA : B 25/03/2023                                                                   4
# * AREA P.A.D.* AREA : B 29/10/2021                                                                   1
# * AREA P.A.D.* AREA : C-D 09/04/2022                                                                 2
# * AREA P.A.D.* AREA : C-D 23/10/2022                                                                 1
# * AREA P.A.D.* AREA : C-D 26/03/2023                                                                 2
# * AREA P.A.D.* AREA : C-D 30/10/2021                                                                 1
# * AREA P.A.D.* AREA : D 09/04/2022                                                                   1
# * AREA P.A.D.* AREA : D 26/03/2023                                                                   1
# * AREA P.A.D.* AREAS * B - C 24/09/2023                                                              1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 21/10/2022                                       1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 22/10/2022                                       1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 23/09/2023                                       1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 23/10/2022                                       1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 24/09/2023                                       1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 28/10/2021                                       1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 29/10/2021                                       1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 30/09/2023                                       1
# * AREA P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 30/10/2021                                       1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA-A 08/10/2021                      3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA-A 10/03/2023                      3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA-A 15/09/2022                      3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA-A 17/03/2022                      3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA-B 08/10/2021                      3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA-B 11/03/2023                      3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA-B 16/09/2022                      3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA-B 18/03/2022                      3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREAS C-D 09/10/2021                   3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREAS C-D 12/03/2023                   3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREAS C-D 17/09/2022                   3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREAS C-D 19/03/2022                   3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - DEPORTISTAS CALIFICADOS 26/02/2022     1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - DISCAPACITADOS 03/09/2023              1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - DISCAPACITADOS 10/09/2022              1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - DISCAPACITADOS 11/02/2023              1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - DISCAPACITADOS 21/09/2021              1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - DISCAPACITADOS 26/02/2022              1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - VICTIMAS DE LA VIOLENCIA 11/02/2023    2
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - VICTIMAS DE LA VIOLENCIA 26/02/2022    1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL 03/09/2023                               1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL 10/09/2022                               1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL 11/02/2023                               3
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL 21/09/2021                               1
# * AREA P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL 26/02/2022                               3
# * UNIDAD P.A.D.* << HUAMACHUCO >> 09/02/2020                                                         1
# * UNIDAD P.A.D.* << HUAMACHUCO >> 10/02/2019                                                         1
# * UNIDAD P.A.D.* << HUAMACHUCO >> 12/08/2018                                                         1
# * UNIDAD P.A.D.* << HUAMACHUCO >> 18/08/2019                                                         1
# * UNIDAD P.A.D.* << JEQUETEPEQUE >> 09/02/2020                                                       1
# * UNIDAD P.A.D.* << JEQUETEPEQUE >> 10/02/2019                                                       1
# Name: count, dtype: int64

# %%
unstacked_titles['third'].value_counts().sort_index().tail(60)
# Out:
# third
# * UNIDAD P.A.D.* << JEQUETEPEQUE >> 12/08/2018                                             1
# * UNIDAD P.A.D.* << JEQUETEPEQUE >> 18/08/2019                                             1
# * UNIDAD P.A.D.* << TRUJILLO >> 09/02/2020                                                 1
# * UNIDAD P.A.D.* << TRUJILLO >> 10/02/2019                                                 1
# * UNIDAD P.A.D.* << TRUJILLO >> 12/08/2018                                                 1
# * UNIDAD P.A.D.* << TRUJILLO >> 18/08/2019                                                 1
# * UNIDAD P.A.D.* AREA : A 02/06/2021                                                       3
# * UNIDAD P.A.D.* AREA : A 02/12/2020                                                       1
# * UNIDAD P.A.D.* AREA : B 03/12/2020                                                       1
# * UNIDAD P.A.D.* AREA : B 28/05/2021                                                       4
# * UNIDAD P.A.D.* AREA : C 04/12/2020                                                       1
# * UNIDAD P.A.D.* AREA : C-D 29/05/2021                                                     2
# * UNIDAD P.A.D.* AREA : D 05/12/2020                                                       1
# * UNIDAD P.A.D.* AREA : D 29/05/2021                                                       1
# * UNIDAD P.A.D.* GRUPO : A 07/03/2020                                                      4
# * UNIDAD P.A.D.* GRUPO : A 09/03/2019                                                      3
# * UNIDAD P.A.D.* GRUPO : A 21/09/2019                                                      1
# * UNIDAD P.A.D.* GRUPO : A 22/09/2018                                                      1
# * UNIDAD P.A.D.* GRUPO : A y B 09/03/2019                                                  1
# * UNIDAD P.A.D.* GRUPO : B 08/03/2020                                                      3
# * UNIDAD P.A.D.* GRUPO : B 10/03/2019                                                      3
# * UNIDAD P.A.D.* GRUPO : B 22/09/2019                                                      1
# * UNIDAD P.A.D.* GRUPO : B 23/09/2018                                                      1
# * UNIDAD P.A.D.* Modalidad : DEPORTISTAS CALIFICADOS 23/02/2020                            1
# * UNIDAD P.A.D.* Modalidad : DEPORTISTAS CALIFICADOS 24/02/2019                            1
# * UNIDAD P.A.D.* Modalidad : DISCAPACITADOS 08/09/2019                                     1
# * UNIDAD P.A.D.* Modalidad : DISCAPACITADOS 12/05/2021                                     1
# * UNIDAD P.A.D.* Modalidad : DISCAPACITADOS 23/02/2020                                     1
# * UNIDAD P.A.D.* Modalidad : DISCAPACITADOS 24/02/2019                                     1
# * UNIDAD P.A.D.* Modalidad : DISCAPACITADOS 26/08/2018                                     1
# * UNIDAD P.A.D.* Modalidad : VICTIMAS DE LA VIOLENCIA 12/05/2021                           1
# * UNIDAD P.A.D.* Modalidad : VICTIMAS DE LA VIOLENCIA 23/02/2020                           1
# * UNIDAD P.A.D.* Modalidad : VICTIMAS DE LA VIOLENCIA 24/02/2019                           1
# * UNIDAD P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 02/12/2020                           1
# * UNIDAD P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 03/12/2020                           1
# * UNIDAD P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 04/12/2020                           1
# * UNIDAD P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 05/12/2020                           1
# * UNIDAD P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 21/09/2019                           1
# * UNIDAD P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 22/09/2018                           1
# * UNIDAD P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 22/09/2019                           1
# * UNIDAD P.A.D.* QUINTO GRADO DE EDUCACION SECUNDARIA 23/09/2018                           1
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA A 05/11/2020          3
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA A 13/05/2021          3
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA B 06/11/2020          3
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA B 14/05/2021          3
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA C-D 07/11/2020        3
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - AREA C-D 15/05/2021        3
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - GRUPOS A y B 08/09/2019    1
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - GRUPOS A y B 23/02/2020    4
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - GRUPOS A y B 24/02/2019    4
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL - GRUPOS A y B 26/08/2018    1
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL 12/05/2021                   3
# * UNIDAD P.A.D.* RESULTADOS GENERALES POR ESCUELA PROFESIONAL 21/11/2020                   1
# RESULTADOS GENERALES POR ESCUELA PROFESIONAL * DEPORTISTAS CALIFICADOS                     1
# RESULTADOS GENERALES POR ESCUELA PROFESIONAL * DISCAPACITADOS                              1
# RESULTADOS GENERALES POR ESCUELA PROFESIONAL * HUAMACHUCO                                  4
# RESULTADOS GENERALES POR ESCUELA PROFESIONAL * STGO.DE CHUCO                               2
# RESULTADOS GENERALES POR ESCUELA PROFESIONAL * TRUJILLO                                    4
# RESULTADOS GENERALES POR ESCUELA PROFESIONAL * V A L L E                                   4
# RESULTADOS GENERALES POR ESCUELA PROFESIONAL * VICT.DE LA VIOLENCIA                        1
# Name: count, dtype: int64

# %% [markdown]
# ## THIRD COLUMN DATES

# %%
# valid_date = re.compile(r'(\d\d/\d\d/\d+)')
nombre = 'third'
third_date = (
    unstacked_titles
    [nombre]
    .str.extract(valid_date)
    [0]
    # .value_counts()
    # .sum()
)

third_date
# Out:
# n_df
# 0      12/08/2018
# 1      12/08/2018
# 2      12/08/2018
# 3      22/09/2018
# 4      23/09/2018
#           ...
# 201    20/08/2023
# 202    20/08/2023
# 203           NaN
# 204           NaN
# 205           NaN
# Name: 0, Length: 206, dtype: object

# %% [markdown]
# ## THIRD COLUMN PLACES

# %%
# valid_places = re.compile(r'(STGO\.DE CHUCO|TRUJILLO|HUAMACHUCO|JEQUETEPEQUE|V A L L E)')

third_places = (
    unstacked_titles
    ['third']
    .str.extract(valid_places)
    [0]
    # .value_counts()
    # .sum()
)

third_places
# Out:
# n_df
# 0          TRUJILLO
# 1      JEQUETEPEQUE
# 2        HUAMACHUCO
# 3               NaN
# 4               NaN
#            ...
# 201       V A L L E
# 202      HUAMACHUCO
# 203      HUAMACHUCO
# 204       V A L L E
# 205        TRUJILLO
# Name: 0, Length: 206, dtype: object

# %% [markdown]
# ## THIRD COLUMN TESTS

# %%
# valid_tests = re.compile(r'(ORDINARIO|CEPUNT|EXTRAORDINARIO)')

third_tests = (
    unstacked_titles
    ['third']
    .str.extract(valid_tests)
    [0]
    # .value_counts()
    # .sum()
)

third_tests.value_counts() # no tiene nada
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ## THIRD COLUMN USERS

# %%
# valid_users = re.compile(r'(DISCAPACITADOS|DEPORTISTAS CALIFICADOS|VICT\.DE LA VIOLENCIA|QUINTO GRADO DE EDUCACION SECUNDARIA)')

third_users = (
    unstacked_titles
    ['third']
    .str.extract(valid_users)
    [0]
    # .value_counts()
    # .sum()
)

third_users.value_counts()
# Out:
# 0
# QUINTO GRADO DE EDUCACION SECUNDARIA    17
# DISCAPACITADOS                          11
# VICTIMAS DE LA VIOLENCIA                 6
# DEPORTISTAS CALIFICADOS                  4
# VICT.DE LA VIOLENCIA                     1
# Name: count, dtype: int64

# %% [markdown]
# ## THIRD COLUMN AREAS

# %%
get_areas = re.compile(r'(AREAS?|GRUPOS?)(.+)\d\d/\d\d/\d+')
duplicated_value = 'AREA P.A.D.'
not_areas = re.compile(r'[^ABCDy-]')
y = 'y'
min_sign = '-'
start_min = re.compile(r'^-')

third_areas = (
    unstacked_titles
    ['third']
    .str.replace(duplicated_value, empty_string, regex=False)
    .str.extract(get_areas)
    [1]
    .replace(not_areas, empty_string, regex=True)
    .str.replace(y, min_sign, regex=False)
    .str.replace(start_min, empty_string, regex=True)
    # .value_counts()
)
third_areas
# Out:
# n_df
# 0      NaN
# 1      NaN
# 2      NaN
# 3        A
# 4        B
#       ...
# 201    NaN
# 202    NaN
# 203    NaN
# 204    NaN
# 205    NaN
# Name: 1, Length: 206, dtype: object

# %% [markdown]
# # FOURTH COLUMN

# %%
(
    unstacked_titles
    ['fourth']
    .value_counts()
)
# Out:
# fourth
# RESULTADOS GENERALES POR ESCUELA PROFESIONAL                                67
# RESULTADOS GENERALES - ORDEN DE MERITO POR ESCUELA ACADEMICO PROFESIONAL    15
# RESULTADOS GENERALES POR ESCUELA PROFESIONAL - GRUPOS A y B                  4
# RESULTADOS POR ESCUELA ACADEMICO PROFESIONAL - AREA - A                      3
# RESULTADOS POR ESCUELA ACADEMICO PROFESIONAL - AREA - B                      3
# RESULTADOS POR ESCUELA ACADEMICO PROFESIONAL - GRUPO A                       2
# RESULTADOS POR ESCUELA ACADEMICO PROFESIONAL - GRUPO B                       2
# RESULTADOS POR ESCUELA ACADEMICO PROFESIONAL - AREA - D                      2
# RESULTADOS POR ESCUELA ACADEMICO PROFESIONAL - AREA - C-D                    2
# RESULTADOS POR ESCUELA ACADEMICO PROFESIONAL - AREA - C                      1
# RESULTADOS POR ESCUELA ACADEMICO PROFESIONAL - AREA * A                      1
# RESULTADOS POR ESCUELA ACADEMICO PROFESIONAL - AREAS * B - C                 1
# Name: count, dtype: int64

# %% [markdown]
# ## FOURTH COLUMN AREAS

# %%
get_areas_2 = re.compile(r'(AREAS?|GRUPOS?)(.+)$')

fourth_areas = (
    unstacked_titles
    ['fourth']
    .str.extract(get_areas_2)
    [1]
    .replace(not_areas, empty_string, regex=True)
    .str.replace(y, min_sign, regex=False)
    .str.replace(start_min, empty_string, regex=True)
    # .value_counts()
    # .sum()
)

fourth_areas
# Out:
# n_df
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 201    NaN
# 202    NaN
# 203    NaN
# 204    NaN
# 205    NaN
# Name: 1, Length: 206, dtype: object

# %% [markdown]
# # UNIENDO TITLES

# %%
first_test

second_tests
second_date
second_places
second_users

third_date
third_places
third_users
third_areas
# third_tests no tiene nada

fourth_areas
# Out:
# n_df
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 201    NaN
# 202    NaN
# 203    NaN
# 204    NaN
# 205    NaN
# Name: 1, Length: 206, dtype: object

# %%
# first_test.value_counts()

(
    second_tests
)
# Out:
# n_df
# 0         CEPUNT
# 1         CEPUNT
# 2         CEPUNT
# 3      ORDINARIO
# 4      ORDINARIO
#          ...
# 201       CEPUNT
# 202       CEPUNT
# 203       CEPUNT
# 204       CEPUNT
# 205       CEPUNT
# Name: 0, Length: 206, dtype: object

# %%
dates_df = (
    second_date
    .str.cat(third_date, na_rep=empty_string)
    .replace(empty_string, np.nan, regex=False)
 )

dates_df
# Out:
# n_df
# 0      12/08/2018
# 1      12/08/2018
# 2      12/08/2018
# 3      22/09/2018
# 4      23/09/2018
#           ...
# 201    20/08/2023
# 202    20/08/2023
# 203    18/02/2024
# 204    18/02/2024
# 205    18/02/2024
# Name: 0, Length: 206, dtype: object

# %%
# pd.concat([second_places, third_places], axis=1)
valle_with_spaces = 'V A L L E'
valle_without_spaces = 'VALLE'

places_df = (
    second_places
    .str.cat(third_places, na_rep=empty_string)
    .replace(empty_string, np.nan, regex=False)
    .replace(valle_with_spaces, valle_without_spaces, regex=False)
)

places_df
# Out:
# n_df
# 0          TRUJILLO
# 1      JEQUETEPEQUE
# 2        HUAMACHUCO
# 3          TRUJILLO
# 4          TRUJILLO
#            ...
# 201           VALLE
# 202      HUAMACHUCO
# 203      HUAMACHUCO
# 204           VALLE
# 205        TRUJILLO
# Name: 0, Length: 206, dtype: object

# %%
# pd.concat([second_users, third_users], axis=1)
users_df = (
    second_users
    .str.cat(third_users, na_rep=empty_string)
    .replace(empty_string, np.nan, regex=False)
)
users_df
# Out:
# n_df
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 201    NaN
# 202    NaN
# 203    NaN
# 204    NaN
# 205    NaN
# Name: 0, Length: 206, dtype: object

# %%
# pd.concat([third_areas, fourth_areas], axis=1)
areas_df = (
    third_areas
    .str.cat(fourth_areas, na_rep=empty_string)
    .replace(empty_string, np.nan, regex=False)
)
areas_df
# Out:
# n_df
# 0      NaN
# 1      NaN
# 2      NaN
# 3        A
# 4        B
#       ...
# 201    NaN
# 202    NaN
# 203    NaN
# 204    NaN
# 205    NaN
# Name: 1, Length: 206, dtype: object

# %% [markdown]
# # RESULTADO FINAL TITLES

# %%
final_columns = ['tipo', 'fecha', 'lugar', 'alumno', 'area']
final_titles_df = (
    pd
    .concat(
        [second_tests,
         dates_df,
         places_df,
         users_df,
         areas_df], axis=1)
)

final_titles_df.columns = final_columns
final_titles_df
# Out:
#            tipo       fecha         lugar alumno area
# n_df
# 0        CEPUNT  12/08/2018      TRUJILLO    NaN  NaN
# 1        CEPUNT  12/08/2018  JEQUETEPEQUE    NaN  NaN
# 2        CEPUNT  12/08/2018    HUAMACHUCO    NaN  NaN
# 3     ORDINARIO  22/09/2018      TRUJILLO    NaN    A
# 4     ORDINARIO  23/09/2018      TRUJILLO    NaN    B
# ...         ...         ...           ...    ...  ...
# 201      CEPUNT  20/08/2023         VALLE    NaN  NaN
# 202      CEPUNT  20/08/2023    HUAMACHUCO    NaN  NaN
# 203      CEPUNT  18/02/2024    HUAMACHUCO    NaN  NaN
# 204      CEPUNT  18/02/2024         VALLE    NaN  NaN
# 205      CEPUNT  18/02/2024      TRUJILLO    NaN  NaN
#
# [206 rows x 5 columns]

# %%
final_titles_df['fecha']
# Out:
# n_df
# 0      12/08/2018
# 1      12/08/2018
# 2      12/08/2018
# 3      22/09/2018
# 4      23/09/2018
#           ...
# 201    20/08/2023
# 202    20/08/2023
# 203    18/02/2024
# 204    18/02/2024
# 205    18/02/2024
# Name: fecha, Length: 206, dtype: object

# %% [markdown]
# # TRANSFORMANDO RESULTADOS

# %% [markdown]
# ## NAMES

# %%
valid_name = re.compile(r'\s(\D+[0]?\D+[0]?)\s-?\d')
# r'(\s\D+[0]?\D+[0]?\s-?\d)'
# r'^\d{4}\s\d{6}([\D]+)\d+\.'

names = (
    raw_results_df
    # .set_index('n_df')
    ['main']
    .str.extract(valid_name)
    [0]
    .str.strip()
)
names
# Out:
# 8         RODRIGUEZ SANCHEZ ROSICELA ELIZABETH
# 9                   LLANOS SOLIS KIMBERLYN YEI
# 10                 ALVA PEREZ TAMARA ANTONELLA
# 11                      URIOL FLORES LIZ ROCIO
# 12                   VASQUEZ GUERRA CESAR IVAN
#                           ...
# 135172              LAZARO LLANOS RICHARD JOEL
# 135173              ALBUJAR VIERA LUIS ALBERTO
# 135174                 POLO REYES JULIO MARTIN
# 135175               ALFARO MEDRANO MARIA JOSE
# 135176                JESUS VEGA CRISTIAN JOEL
# Name: 0, Length: 115385, dtype: object

# %%
# names[0].notnull().sum()

# %% [markdown]
# ## GRADES

# %%
valid_grades = re.compile(r'(-?\d+\.\d+)')

grades = (
    raw_results_df
    # .set_index('n_df')
    ['main']
    .str.extractall(valid_grades)
    .unstack()
    .droplevel(level=0, axis=1)
)
grades
# Out:
# match        0       1        2        3       4
# 8       41.577  78.261  126.368  246.206  94.842
# 9       37.504  67.242  109.044  213.790  94.842
# 10      48.918  53.192  109.036  211.146  94.842
# 11      39.342  57.783  102.429  199.554  94.842
# 12      35.462  50.730  109.548  195.740  94.842
# ...        ...     ...      ...      ...     ...
# 135172  31.799  42.197   73.996      NaN     NaN
# 135173  28.948  27.507   56.455      NaN     NaN
# 135174  14.262  24.459   38.721      NaN     NaN
# 135175  18.346  18.952   37.298      NaN     NaN
# 135176  -0.422  25.675   25.253      NaN     NaN
#
# [115385 rows x 5 columns]

# %%
grades
# Out:
# match        0       1        2        3       4
# 8       41.577  78.261  126.368  246.206  94.842
# 9       37.504  67.242  109.044  213.790  94.842
# 10      48.918  53.192  109.036  211.146  94.842
# 11      39.342  57.783  102.429  199.554  94.842
# 12      35.462  50.730  109.548  195.740  94.842
# ...        ...     ...      ...      ...     ...
# 135172  31.799  42.197   73.996      NaN     NaN
# 135173  28.948  27.507   56.455      NaN     NaN
# 135174  14.262  24.459   38.721      NaN     NaN
# 135175  18.346  18.952   37.298      NaN     NaN
# 135176  -0.422  25.675   25.253      NaN     NaN
#
# [115385 rows x 5 columns]

# %% [markdown]
# ## SCHOOL AND DETAILS

# %%
after_grades = re.compile(r'(\.\d+\s[A-Z].*)')
digits = re.compile(r'\.\d+\s')
empty_string = ''

school_and_details = (
        raw_results_df
        ['main']
        .str.extract(after_grades)
        [0]
        .str.replace(digits, empty_string, regex=True)
)

school_and_details
# Out:
# 8           SI ADMINISTRACION
# 9           SI ADMINISTRACION
# 10          SI ADMINISTRACION
# 11          SI ADMINISTRACION
# 12          SI ADMINISTRACION
#                  ...
# 135172    ED.SEC: HISTORIA NO
# 135173    ED.SEC: HISTORIA NO
# 135174    ED.SEC: HISTORIA NO
# 135175    ED.SEC: HISTORIA NO
# 135176    ED.SEC: HISTORIA NO
# Name: 0, Length: 115385, dtype: object

# %%
school_and_details
# Out:
# 8           SI ADMINISTRACION
# 9           SI ADMINISTRACION
# 10          SI ADMINISTRACION
# 11          SI ADMINISTRACION
# 12          SI ADMINISTRACION
#                  ...
# 135172    ED.SEC: HISTORIA NO
# 135173    ED.SEC: HISTORIA NO
# 135174    ED.SEC: HISTORIA NO
# 135175    ED.SEC: HISTORIA NO
# 135176    ED.SEC: HISTORIA NO
# Name: 0, Length: 115385, dtype: object

# %% [markdown]
# ### DETAILS

# %%
valid_result = re.compile(r'(INGRESA.*|NO\sINGRESA.*|ING\.\s?2.*|AUSENTE.*|ANULADO.*|^SI\s|^NO\s|\sSI$|\sNO$)')
possitive_pattern = re.compile(r'INGRESA([\w\s-]+)?')
negative_pattern = re.compile(r'NO\D+')
positive_result = 'SI'
negative_result = 'NO'

# r'(INGRESA|NO\sINGRESA|ING\.\s?2.*|AUSENTE.*|ANULADO.*|^SI\s|^NO\s|\sSI$|\sNO$)'
details = (
        school_and_details
        .str.extract(valid_result)
        [0]
        .str.strip()
        .str.replace(negative_pattern, negative_result, regex=True)
        .str.replace(possitive_pattern, positive_result, regex=True)
)
details
# Out:
# 8         SI
# 9         SI
# 10        SI
# 11        SI
# 12        SI
#           ..
# 135172    NO
# 135173    NO
# 135174    NO
# 135175    NO
# 135176    NO
# Name: 0, Length: 115385, dtype: object

# %%
# details[details.isnull()]
details.value_counts()
# Out:
# 0
# NO            95052
# SI            15745
# AUSENTE        3003
# ING. 2-OPC     1564
# ANULADO          20
# Name: count, dtype: int64

# %% [markdown]
# ### SCHOOL

# %%
valid_result2 = re.compile(r'INGRESA.*|NO\sINGRESA.*|ING\.\s?2.*|AUSENTE.*|ANULADO.*|^SI\s|^NO\s|\sSI$|\sNO$')

school = (
    school_and_details
    .str.replace(valid_result2, empty_string, regex=True)
    .str.upper()
    .str.strip()
    
)
school
# Out:
# 8           ADMINISTRACION
# 9           ADMINISTRACION
# 10          ADMINISTRACION
# 11          ADMINISTRACION
# 12          ADMINISTRACION
#                 ...
# 135172    ED.SEC: HISTORIA
# 135173    ED.SEC: HISTORIA
# 135174    ED.SEC: HISTORIA
# 135175    ED.SEC: HISTORIA
# 135176    ED.SEC: HISTORIA
# Name: 0, Length: 115385, dtype: object

# %%
school.notnull().sum()
# Out:
# 115385

# %%
school_and_details[88692]
# Out:
# 'MATEMATICAS'

# %%
raw_results_df.loc[88692]['main']
# Out:
# '0013 026335 PAREDES QUEZADA DEIVER SANTOS 25.409 -8.218 17.191 53.635 MATEMATICAS'

# %% [markdown]
# ## JOIN RESULTS

# %%
combine_result = pd.concat(
    [
        names,
        grades,
        school,
        details,
        raw_results_df['n_df']
    ], axis=1    
)

combine_result.columns = ['names', 'r1', 'r2', 'r3', 'r4', 'r5', 'escuela', 'resultado', 'n_df']
combine_result
# Out:
#                                        names      r1      r2       r3  \
# 8       RODRIGUEZ SANCHEZ ROSICELA ELIZABETH  41.577  78.261  126.368
# 9                 LLANOS SOLIS KIMBERLYN YEI  37.504  67.242  109.044
# 10               ALVA PEREZ TAMARA ANTONELLA  48.918  53.192  109.036
# 11                    URIOL FLORES LIZ ROCIO  39.342  57.783  102.429
# 12                 VASQUEZ GUERRA CESAR IVAN  35.462  50.730  109.548
# ...                                      ...     ...     ...      ...
# 135172            LAZARO LLANOS RICHARD JOEL  31.799  42.197   73.996
# 135173            ALBUJAR VIERA LUIS ALBERTO  28.948  27.507   56.455
# 135174               POLO REYES JULIO MARTIN  14.262  24.459   38.721
# 135175             ALFARO MEDRANO MARIA JOSE  18.346  18.952   37.298
# 135176              JESUS VEGA CRISTIAN JOEL  -0.422  25.675   25.253
#
#              r4      r5           escuela resultado  n_df
# 8       246.206  94.842    ADMINISTRACION        SI     0
# 9       213.790  94.842    ADMINISTRACION        SI     0
# 10      211.146  94.842    ADMINISTRACION        SI     0
# 11      199.554  94.842    ADMINISTRACION        SI     0
# 12      195.740  94.842    ADMINISTRACION        SI     0
# ...         ...     ...               ...       ...   ...
# 135172      NaN     NaN  ED.SEC: HISTORIA        NO   205
# 135173      NaN     NaN  ED.SEC: HISTORIA        NO   205
# 135174      NaN     NaN  ED.SEC: HISTORIA        NO   205
# 135175      NaN     NaN  ED.SEC: HISTORIA        NO   205
# 135176      NaN     NaN  ED.SEC: HISTORIA        NO   205
#
# [115385 rows x 9 columns]

# %%
combine_result.loc[88692]['names']
# Out:
# 'PAREDES QUEZADA DEIVER SANTOS'

# %%
combine_result
# Out:
#                                        names      r1      r2       r3  \
# 8       RODRIGUEZ SANCHEZ ROSICELA ELIZABETH  41.577  78.261  126.368
# 9                 LLANOS SOLIS KIMBERLYN YEI  37.504  67.242  109.044
# 10               ALVA PEREZ TAMARA ANTONELLA  48.918  53.192  109.036
# 11                    URIOL FLORES LIZ ROCIO  39.342  57.783  102.429
# 12                 VASQUEZ GUERRA CESAR IVAN  35.462  50.730  109.548
# ...                                      ...     ...     ...      ...
# 135172            LAZARO LLANOS RICHARD JOEL  31.799  42.197   73.996
# 135173            ALBUJAR VIERA LUIS ALBERTO  28.948  27.507   56.455
# 135174               POLO REYES JULIO MARTIN  14.262  24.459   38.721
# 135175             ALFARO MEDRANO MARIA JOSE  18.346  18.952   37.298
# 135176              JESUS VEGA CRISTIAN JOEL  -0.422  25.675   25.253
#
#              r4      r5           escuela resultado  n_df
# 8       246.206  94.842    ADMINISTRACION        SI     0
# 9       213.790  94.842    ADMINISTRACION        SI     0
# 10      211.146  94.842    ADMINISTRACION        SI     0
# 11      199.554  94.842    ADMINISTRACION        SI     0
# 12      195.740  94.842    ADMINISTRACION        SI     0
# ...         ...     ...               ...       ...   ...
# 135172      NaN     NaN  ED.SEC: HISTORIA        NO   205
# 135173      NaN     NaN  ED.SEC: HISTORIA        NO   205
# 135174      NaN     NaN  ED.SEC: HISTORIA        NO   205
# 135175      NaN     NaN  ED.SEC: HISTORIA        NO   205
# 135176      NaN     NaN  ED.SEC: HISTORIA        NO   205
#
# [115385 rows x 9 columns]

# %% [markdown]
# # UNIENDO TITLES CON RESULTS

# %%
results_with_titles = pd.merge(
    combine_result,
    final_titles_df,
    left_on='n_df',
    right_index=True
)

results_with_titles
# Out:
#                                        names      r1      r2       r3  \
# 8       RODRIGUEZ SANCHEZ ROSICELA ELIZABETH  41.577  78.261  126.368
# 9                 LLANOS SOLIS KIMBERLYN YEI  37.504  67.242  109.044
# 10               ALVA PEREZ TAMARA ANTONELLA  48.918  53.192  109.036
# 11                    URIOL FLORES LIZ ROCIO  39.342  57.783  102.429
# 12                 VASQUEZ GUERRA CESAR IVAN  35.462  50.730  109.548
# ...                                      ...     ...     ...      ...
# 135172            LAZARO LLANOS RICHARD JOEL  31.799  42.197   73.996
# 135173            ALBUJAR VIERA LUIS ALBERTO  28.948  27.507   56.455
# 135174               POLO REYES JULIO MARTIN  14.262  24.459   38.721
# 135175             ALFARO MEDRANO MARIA JOSE  18.346  18.952   37.298
# 135176              JESUS VEGA CRISTIAN JOEL  -0.422  25.675   25.253
#
#              r4      r5           escuela resultado  n_df    tipo       fecha  \
# 8       246.206  94.842    ADMINISTRACION        SI     0  CEPUNT  12/08/2018
# 9       213.790  94.842    ADMINISTRACION        SI     0  CEPUNT  12/08/2018
# 10      211.146  94.842    ADMINISTRACION        SI     0  CEPUNT  12/08/2018
# 11      199.554  94.842    ADMINISTRACION        SI     0  CEPUNT  12/08/2018
# 12      195.740  94.842    ADMINISTRACION        SI     0  CEPUNT  12/08/2018
# ...         ...     ...               ...       ...   ...     ...         ...
# 135172      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT  18/02/2024
# 135173      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT  18/02/2024
# 135174      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT  18/02/2024
# 135175      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT  18/02/2024
# 135176      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT  18/02/2024
#
#            lugar alumno area
# 8       TRUJILLO    NaN  NaN
# 9       TRUJILLO    NaN  NaN
# 10      TRUJILLO    NaN  NaN
# 11      TRUJILLO    NaN  NaN
# 12      TRUJILLO    NaN  NaN
# ...          ...    ...  ...
# 135172  TRUJILLO    NaN  NaN
# 135173  TRUJILLO    NaN  NaN
# 135174  TRUJILLO    NaN  NaN
# 135175  TRUJILLO    NaN  NaN
# 135176  TRUJILLO    NaN  NaN
#
# [115385 rows x 14 columns]

# %%
results_with_titles.loc[88692]
# results_with_titles['fecha'].notnull().sum()
# Out:
# names        PAREDES QUEZADA DEIVER SANTOS
# r1                                  25.409
# r2                                  -8.218
# r3                                  17.191
# r4                                  53.635
# r5                                     NaN
# escuela                        MATEMATICAS
# resultado                              NaN
# n_df                                   149
# tipo                             ORDINARIO
# fecha                           22/10/2022
# lugar                             TRUJILLO
# alumno                                 NaN
# area                                     B
# Name: 88692, dtype: object

# %% [markdown]
# # AGREGANDO I Y PERIODO

# %%
# results_exampanded = (
#     pd.to_datetime(
#         results_with_titles['fecha'],
#         format='%d/%m/%Y'
#     )
# )
# results_exampanded
results_with_titles['fecha'] = (
    pd.to_datetime(
        results_with_titles['fecha'],
        format="%d/%m/%Y"
    )
)
results_with_titles
# Out:
#                                        names      r1      r2       r3  \
# 8       RODRIGUEZ SANCHEZ ROSICELA ELIZABETH  41.577  78.261  126.368
# 9                 LLANOS SOLIS KIMBERLYN YEI  37.504  67.242  109.044
# 10               ALVA PEREZ TAMARA ANTONELLA  48.918  53.192  109.036
# 11                    URIOL FLORES LIZ ROCIO  39.342  57.783  102.429
# 12                 VASQUEZ GUERRA CESAR IVAN  35.462  50.730  109.548
# ...                                      ...     ...     ...      ...
# 135172            LAZARO LLANOS RICHARD JOEL  31.799  42.197   73.996
# 135173            ALBUJAR VIERA LUIS ALBERTO  28.948  27.507   56.455
# 135174               POLO REYES JULIO MARTIN  14.262  24.459   38.721
# 135175             ALFARO MEDRANO MARIA JOSE  18.346  18.952   37.298
# 135176              JESUS VEGA CRISTIAN JOEL  -0.422  25.675   25.253
#
#              r4      r5           escuela resultado  n_df    tipo      fecha  \
# 8       246.206  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 9       213.790  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 10      211.146  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 11      199.554  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 12      195.740  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# ...         ...     ...               ...       ...   ...     ...        ...
# 135172      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 135173      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 135174      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 135175      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 135176      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
#
#            lugar alumno area
# 8       TRUJILLO    NaN  NaN
# 9       TRUJILLO    NaN  NaN
# 10      TRUJILLO    NaN  NaN
# 11      TRUJILLO    NaN  NaN
# 12      TRUJILLO    NaN  NaN
# ...          ...    ...  ...
# 135172  TRUJILLO    NaN  NaN
# 135173  TRUJILLO    NaN  NaN
# 135174  TRUJILLO    NaN  NaN
# 135175  TRUJILLO    NaN  NaN
# 135176  TRUJILLO    NaN  NaN
#
# [115385 rows x 14 columns]

# %%
results_with_titles['year'] = (
    results_with_titles
    ['fecha']
    .dt.year
)
results_with_titles
# Out:
#                                        names      r1      r2       r3  \
# 8       RODRIGUEZ SANCHEZ ROSICELA ELIZABETH  41.577  78.261  126.368
# 9                 LLANOS SOLIS KIMBERLYN YEI  37.504  67.242  109.044
# 10               ALVA PEREZ TAMARA ANTONELLA  48.918  53.192  109.036
# 11                    URIOL FLORES LIZ ROCIO  39.342  57.783  102.429
# 12                 VASQUEZ GUERRA CESAR IVAN  35.462  50.730  109.548
# ...                                      ...     ...     ...      ...
# 135172            LAZARO LLANOS RICHARD JOEL  31.799  42.197   73.996
# 135173            ALBUJAR VIERA LUIS ALBERTO  28.948  27.507   56.455
# 135174               POLO REYES JULIO MARTIN  14.262  24.459   38.721
# 135175             ALFARO MEDRANO MARIA JOSE  18.346  18.952   37.298
# 135176              JESUS VEGA CRISTIAN JOEL  -0.422  25.675   25.253
#
#              r4      r5           escuela resultado  n_df    tipo      fecha  \
# 8       246.206  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 9       213.790  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 10      211.146  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 11      199.554  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 12      195.740  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# ...         ...     ...               ...       ...   ...     ...        ...
# 135172      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 135173      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 135174      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 135175      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 135176      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
#
#            lugar alumno area  year
# 8       TRUJILLO    NaN  NaN  2018
# 9       TRUJILLO    NaN  NaN  2018
# 10      TRUJILLO    NaN  NaN  2018
# 11      TRUJILLO    NaN  NaN  2018
# 12      TRUJILLO    NaN  NaN  2018
# ...          ...    ...  ...   ...
# 135172  TRUJILLO    NaN  NaN  2024
# 135173  TRUJILLO    NaN  NaN  2024
# 135174  TRUJILLO    NaN  NaN  2024
# 135175  TRUJILLO    NaN  NaN  2024
# 135176  TRUJILLO    NaN  NaN  2024
#
# [115385 rows x 15 columns]

# %%
results_with_titles['month'] = (
    results_with_titles
    ['fecha']
    .dt.month
)

# %%
# results_with_titles['fecha'].dt.month > 6
filter_by_month = (
    results_with_titles
    ['fecha']
    .dt.month > 6
)
filter_by_month

results_with_titles.loc[filter_by_month, "number"] = "I"
results_with_titles.loc[~filter_by_month, "number"] = "II"

# %%
results_with_titles['number'].value_counts()
# Out:
# number
# II    61293
# I     54092
# Name: count, dtype: int64

# %%
# results_with_titles['month'].apply(lambda month: "I" if month > 6 else "II" )
filter_by_number = (
    results_with_titles
    ['number'] == "I"
)

results_with_titles.loc[filter_by_number, "periodo"] = results_with_titles["fecha"].dt.year + 1
results_with_titles.loc[~filter_by_number, "periodo"] = results_with_titles["fecha"].dt.year

# %%
results_with_titles[['number', 'periodo']].value_counts()
# Out:
# number  periodo
# I       2024.0     12058
# II      2024.0     11660
#         2023.0     11547
# I       2023.0     10869
# II      2020.0     10308
#         2022.0     10272
#         2019.0      9674
# I       2020.0      9557
#         2019.0      9357
#         2022.0      8109
# II      2021.0      7832
# I       2021.0      4142
# Name: count, dtype: int64

# %%
results_with_titles[['number', 'periodo', 'year', 'month']].value_counts()
# Out:
# number  periodo  year  month
# II      2023.0   2023  3        10906
#         2024.0   2024  3         7962
# I       2024.0   2023  9         7936
#         2022.0   2021  10        7875
#         2023.0   2022  10        7605
# II      2020.0   2020  3         6610
#         2022.0   2022  4         6430
#         2021.0   2021  5         6366
# I       2020.0   2019  9         6357
# II      2019.0   2019  3         6174
# I       2019.0   2018  9         5718
#         2024.0   2023  8         4122
# II      2020.0   2020  2         3698
#         2024.0   2024  2         3698
# I       2019.0   2018  8         3639
# II      2019.0   2019  2         3500
#         2022.0   2022  3         3302
# I       2023.0   2022  9         3264
#         2020.0   2019  8         3200
#         2021.0   2020  12        2514
#                        11        1628
# II      2021.0   2021  6         1466
#         2023.0   2023  2          641
#         2022.0   2022  2          540
# I       2022.0   2021  9          234
# Name: count, dtype: int64

# %%
results_with_titles
# Out:
#                                        names      r1      r2       r3  \
# 8       RODRIGUEZ SANCHEZ ROSICELA ELIZABETH  41.577  78.261  126.368
# 9                 LLANOS SOLIS KIMBERLYN YEI  37.504  67.242  109.044
# 10               ALVA PEREZ TAMARA ANTONELLA  48.918  53.192  109.036
# 11                    URIOL FLORES LIZ ROCIO  39.342  57.783  102.429
# 12                 VASQUEZ GUERRA CESAR IVAN  35.462  50.730  109.548
# ...                                      ...     ...     ...      ...
# 135172            LAZARO LLANOS RICHARD JOEL  31.799  42.197   73.996
# 135173            ALBUJAR VIERA LUIS ALBERTO  28.948  27.507   56.455
# 135174               POLO REYES JULIO MARTIN  14.262  24.459   38.721
# 135175             ALFARO MEDRANO MARIA JOSE  18.346  18.952   37.298
# 135176              JESUS VEGA CRISTIAN JOEL  -0.422  25.675   25.253
#
#              r4      r5           escuela resultado  n_df    tipo      fecha  \
# 8       246.206  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 9       213.790  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 10      211.146  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 11      199.554  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 12      195.740  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# ...         ...     ...               ...       ...   ...     ...        ...
# 135172      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 135173      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 135174      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 135175      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 135176      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
#
#            lugar alumno area  year  month number  periodo
# 8       TRUJILLO    NaN  NaN  2018      8      I   2019.0
# 9       TRUJILLO    NaN  NaN  2018      8      I   2019.0
# 10      TRUJILLO    NaN  NaN  2018      8      I   2019.0
# 11      TRUJILLO    NaN  NaN  2018      8      I   2019.0
# 12      TRUJILLO    NaN  NaN  2018      8      I   2019.0
# ...          ...    ...  ...   ...    ...    ...      ...
# 135172  TRUJILLO    NaN  NaN  2024      2     II   2024.0
# 135173  TRUJILLO    NaN  NaN  2024      2     II   2024.0
# 135174  TRUJILLO    NaN  NaN  2024      2     II   2024.0
# 135175  TRUJILLO    NaN  NaN  2024      2     II   2024.0
# 135176  TRUJILLO    NaN  NaN  2024      2     II   2024.0
#
# [115385 rows x 18 columns]

# %%
results_with_titles['periodo'] = results_with_titles['periodo'].astype(int)
results_with_titles
# Out:
#                                        names      r1      r2       r3  \
# 8       RODRIGUEZ SANCHEZ ROSICELA ELIZABETH  41.577  78.261  126.368
# 9                 LLANOS SOLIS KIMBERLYN YEI  37.504  67.242  109.044
# 10               ALVA PEREZ TAMARA ANTONELLA  48.918  53.192  109.036
# 11                    URIOL FLORES LIZ ROCIO  39.342  57.783  102.429
# 12                 VASQUEZ GUERRA CESAR IVAN  35.462  50.730  109.548
# ...                                      ...     ...     ...      ...
# 135172            LAZARO LLANOS RICHARD JOEL  31.799  42.197   73.996
# 135173            ALBUJAR VIERA LUIS ALBERTO  28.948  27.507   56.455
# 135174               POLO REYES JULIO MARTIN  14.262  24.459   38.721
# 135175             ALFARO MEDRANO MARIA JOSE  18.346  18.952   37.298
# 135176              JESUS VEGA CRISTIAN JOEL  -0.422  25.675   25.253
#
#              r4      r5           escuela resultado  n_df    tipo      fecha  \
# 8       246.206  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 9       213.790  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 10      211.146  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 11      199.554  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 12      195.740  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# ...         ...     ...               ...       ...   ...     ...        ...
# 135172      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 135173      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 135174      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 135175      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 135176      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
#
#            lugar alumno area  year  month number  periodo
# 8       TRUJILLO    NaN  NaN  2018      8      I     2019
# 9       TRUJILLO    NaN  NaN  2018      8      I     2019
# 10      TRUJILLO    NaN  NaN  2018      8      I     2019
# 11      TRUJILLO    NaN  NaN  2018      8      I     2019
# 12      TRUJILLO    NaN  NaN  2018      8      I     2019
# ...          ...    ...  ...   ...    ...    ...      ...
# 135172  TRUJILLO    NaN  NaN  2024      2     II     2024
# 135173  TRUJILLO    NaN  NaN  2024      2     II     2024
# 135174  TRUJILLO    NaN  NaN  2024      2     II     2024
# 135175  TRUJILLO    NaN  NaN  2024      2     II     2024
# 135176  TRUJILLO    NaN  NaN  2024      2     II     2024
#
# [115385 rows x 18 columns]

# %% [markdown]
# # RESETEANDO INDEX

# %%
results_with_titles.reset_index(inplace=True)
del results_with_titles['index']
results_with_titles
# Out:
#                                        names      r1      r2       r3  \
# 0       RODRIGUEZ SANCHEZ ROSICELA ELIZABETH  41.577  78.261  126.368
# 1                 LLANOS SOLIS KIMBERLYN YEI  37.504  67.242  109.044
# 2                ALVA PEREZ TAMARA ANTONELLA  48.918  53.192  109.036
# 3                     URIOL FLORES LIZ ROCIO  39.342  57.783  102.429
# 4                  VASQUEZ GUERRA CESAR IVAN  35.462  50.730  109.548
# ...                                      ...     ...     ...      ...
# 115380            LAZARO LLANOS RICHARD JOEL  31.799  42.197   73.996
# 115381            ALBUJAR VIERA LUIS ALBERTO  28.948  27.507   56.455
# 115382               POLO REYES JULIO MARTIN  14.262  24.459   38.721
# 115383             ALFARO MEDRANO MARIA JOSE  18.346  18.952   37.298
# 115384              JESUS VEGA CRISTIAN JOEL  -0.422  25.675   25.253
#
#              r4      r5           escuela resultado  n_df    tipo      fecha  \
# 0       246.206  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 1       213.790  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 2       211.146  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 3       199.554  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# 4       195.740  94.842    ADMINISTRACION        SI     0  CEPUNT 2018-08-12
# ...         ...     ...               ...       ...   ...     ...        ...
# 115380      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 115381      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 115382      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 115383      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
# 115384      NaN     NaN  ED.SEC: HISTORIA        NO   205  CEPUNT 2024-02-18
#
#            lugar alumno area  year  month number  periodo
# 0       TRUJILLO    NaN  NaN  2018      8      I     2019
# 1       TRUJILLO    NaN  NaN  2018      8      I     2019
# 2       TRUJILLO    NaN  NaN  2018      8      I     2019
# 3       TRUJILLO    NaN  NaN  2018      8      I     2019
# 4       TRUJILLO    NaN  NaN  2018      8      I     2019
# ...          ...    ...  ...   ...    ...    ...      ...
# 115380  TRUJILLO    NaN  NaN  2024      2     II     2024
# 115381  TRUJILLO    NaN  NaN  2024      2     II     2024
# 115382  TRUJILLO    NaN  NaN  2024      2     II     2024
# 115383  TRUJILLO    NaN  NaN  2024      2     II     2024
# 115384  TRUJILLO    NaN  NaN  2024      2     II     2024
#
# [115385 rows x 18 columns]

# %% [markdown]
# # ELIMINADO PUNTAJES

# %%
filter_by_cepunt = results_with_titles['tipo'] == 'CEPUNT'

# %%
filter_by_periodo = results_with_titles['periodo'].isin([2019, 2020])

# %%
puntaje_4 = results_with_titles[(filter_by_cepunt) & (filter_by_periodo)]
puntaje_4
# Out:
#                                       names      r1      r2       r3       r4  \
# 0      RODRIGUEZ SANCHEZ ROSICELA ELIZABETH  41.577  78.261  126.368  246.206
# 1                LLANOS SOLIS KIMBERLYN YEI  37.504  67.242  109.044  213.790
# 2               ALVA PEREZ TAMARA ANTONELLA  48.918  53.192  109.036  211.146
# 3                    URIOL FLORES LIZ ROCIO  39.342  57.783  102.429  199.554
# 4                 VASQUEZ GUERRA CESAR IVAN  35.462  50.730  109.548  195.740
# ...                                     ...     ...     ...      ...      ...
# 31547              LAYZA SANCHEZ ELVIS ALEX   5.900   7.619    7.111   20.630
# 31548                INFANTES REYES JONATAN   2.238   7.939    7.085   17.262
# 31549     SANCHEZ FERNANDEZ SAMUEL JHONATAN   1.827  12.527    0.000   14.354
# 31550                    CAIPO POLO HILARIO   5.900   0.000    0.000    5.900
# 31551         SANDOVAL SEGURA DENNI MANFRED  -0.826   0.295    0.000   -0.531
#
#            r5         escuela resultado  n_df    tipo      fecha       lugar  \
# 0      94.842  ADMINISTRACION        SI     0  CEPUNT 2018-08-12    TRUJILLO
# 1      94.842  ADMINISTRACION        SI     0  CEPUNT 2018-08-12    TRUJILLO
# 2      94.842  ADMINISTRACION        SI     0  CEPUNT 2018-08-12    TRUJILLO
# 3      94.842  ADMINISTRACION        SI     0  CEPUNT 2018-08-12    TRUJILLO
# 4      94.842  ADMINISTRACION        SI     0  CEPUNT 2018-08-12    TRUJILLO
# ...       ...             ...       ...   ...     ...        ...         ...
# 31547  44.190    ING.DE MINAS        NO    37  CEPUNT 2020-02-09  HUAMACHUCO
# 31548  44.190    ING.DE MINAS        NO    37  CEPUNT 2020-02-09  HUAMACHUCO
# 31549  44.190    ING.DE MINAS        NO    37  CEPUNT 2020-02-09  HUAMACHUCO
# 31550  44.190    ING.DE MINAS        NO    37  CEPUNT 2020-02-09  HUAMACHUCO
# 31551  44.190    ING.DE MINAS        NO    37  CEPUNT 2020-02-09  HUAMACHUCO
#
#       alumno area  year  month number  periodo
# 0        NaN  NaN  2018      8      I     2019
# 1        NaN  NaN  2018      8      I     2019
# 2        NaN  NaN  2018      8      I     2019
# 3        NaN  NaN  2018      8      I     2019
# 4        NaN  NaN  2018      8      I     2019
# ...      ...  ...   ...    ...    ...      ...
# 31547    NaN  NaN  2020      2     II     2020
# 31548    NaN  NaN  2020      2     II     2020
# 31549    NaN  NaN  2020      2     II     2020
# 31550    NaN  NaN  2020      2     II     2020
# 31551    NaN  NaN  2020      2     II     2020
#
# [12292 rows x 18 columns]

# %%
# puntaje_4.drop(['r1', 'r2', 'r3', 'r5'], axis=1)
puntaje_4.rename(columns={'r4': 'puntaje'}, inplace=True)
puntaje_4
# Out:
# /tmp/ipykernel_4696/4072426375.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   puntaje_4.rename(columns={'r4': 'puntaje'}, inplace=True)
#                                       names  puntaje         escuela  \
# 0      RODRIGUEZ SANCHEZ ROSICELA ELIZABETH  246.206  ADMINISTRACION
# 1                LLANOS SOLIS KIMBERLYN YEI  213.790  ADMINISTRACION
# 2               ALVA PEREZ TAMARA ANTONELLA  211.146  ADMINISTRACION
# 3                    URIOL FLORES LIZ ROCIO  199.554  ADMINISTRACION
# 4                 VASQUEZ GUERRA CESAR IVAN  195.740  ADMINISTRACION
# ...                                     ...      ...             ...
# 31547              LAYZA SANCHEZ ELVIS ALEX   20.630    ING.DE MINAS
# 31548                INFANTES REYES JONATAN   17.262    ING.DE MINAS
# 31549     SANCHEZ FERNANDEZ SAMUEL JHONATAN   14.354    ING.DE MINAS
# 31550                    CAIPO POLO HILARIO    5.900    ING.DE MINAS
# 31551         SANDOVAL SEGURA DENNI MANFRED   -0.531    ING.DE MINAS
#
#       resultado  n_df    tipo      fecha       lugar alumno area  year  month  \
# 0            SI     0  CEPUNT 2018-08-12    TRUJILLO    NaN  NaN  2018      8
# 1            SI     0  CEPUNT 2018-08-12    TRUJILLO    NaN  NaN  2018      8
# 2            SI     0  CEPUNT 2018-08-12    TRUJILLO    NaN  NaN  2018      8
# 3            SI     0  CEPUNT 2018-08-12    TRUJILLO    NaN  NaN  2018      8
# 4            SI     0  CEPUNT 2018-08-12    TRUJILLO    NaN  NaN  2018      8
# ...         ...   ...     ...        ...         ...    ...  ...   ...    ...
# 31547        NO    37  CEPUNT 2020-02-09  HUAMACHUCO    NaN  NaN  2020      2
# 31548        NO    37  CEPUNT 2020-02-09  HUAMACHUCO    NaN  NaN  2020      2
# 31549        NO    37  CEPUNT 2020-02-09  HUAMACHUCO    NaN  NaN  2020      2
# 31550        NO    37  CEPUNT 2020-02-09  HUAMACHUCO    NaN  NaN  2020      2
# 31551        NO    37  CEPUNT 2020-02-09  HUAMACHUCO    NaN  NaN  2020      2
#
#       number  periodo
# 0          I     2019
# 1          I     2019
# 2          I     2019
# 3          I     2019
# 4          I     2019
# ...      ...      ...
# 31547     II     2020
# 31548     II     2020
# 31549     II     2020
# 31550     II     2020
# 31551     II     2020
#
# [12292 rows x 14 columns]

# %%
filter_by_tipo = results_with_titles['tipo'].isin(["EXTRAORDINARIO", "ORDINARIO"])
filter_by_periodo2 = results_with_titles['periodo'] == 2024
filter_by_number2 = results_with_titles['number'] == "II"

# %%
puntaje1 = results_with_titles[(filter_by_tipo) & (filter_by_periodo2) & (filter_by_number2)]
puntaje1
# Out:
#                                       names       r1   r2   r3   r4   r5  \
# 99603          CASTRO GARCIA PAULO GAMALIEL  147.835  NaN  NaN  NaN  NaN
# 99604            PONCE SALVADOR NAOMI BELEN  126.434  NaN  NaN  NaN  NaN
# 99605          PINTADO PEÑA LUCIANA NICOLLE  124.382  NaN  NaN  NaN  NaN
# 99606        LEZAMA DIAZ JENNIFER ANGHELINA  124.377  NaN  NaN  NaN  NaN
# 99607     ABILA VILLANUEVA ADRIANA AMPARITO  123.361  NaN  NaN  NaN  NaN
# ...                                     ...      ...  ...  ...  ...  ...
# 107560          CASTILLO ROJAS HUGO GABRIEL    4.044  NaN  NaN  NaN  NaN
# 107561           RUIZ JACOBO MERLY MILAGROS    0.986  NaN  NaN  NaN  NaN
# 107562        ULLOA FLORES MANUEL JHAN FRAN   -0.100  NaN  NaN  NaN  NaN
# 107563  CONTRERAS GUTIERREZ BRAYAN MERCEDES   -4.159  NaN  NaN  NaN  NaN
# 107564          GARCIA CORONEL YOHAN ESMITH   -7.202  NaN  NaN  NaN  NaN
#
#                escuela resultado  n_df            tipo      fecha  \
# 99603   ADMINISTRACION        SI   186  EXTRAORDINARIO 2024-03-03
# 99604   ADMINISTRACION        SI   186  EXTRAORDINARIO 2024-03-03
# 99605   ADMINISTRACION        SI   186  EXTRAORDINARIO 2024-03-03
# 99606   ADMINISTRACION        SI   186  EXTRAORDINARIO 2024-03-03
# 99607   ADMINISTRACION        SI   186  EXTRAORDINARIO 2024-03-03
# ...                ...       ...   ...             ...        ...
# 107560   ING.AMBIENTAL        NO   199       ORDINARIO 2024-03-17
# 107561   ING.AMBIENTAL        NO   199       ORDINARIO 2024-03-17
# 107562   ING.AMBIENTAL        NO   199       ORDINARIO 2024-03-17
# 107563   ING.AMBIENTAL        NO   199       ORDINARIO 2024-03-17
# 107564   ING.AMBIENTAL        NO   199       ORDINARIO 2024-03-17
#
#                 lugar alumno area  year  month number  periodo
# 99603        TRUJILLO    NaN  NaN  2024      3     II     2024
# 99604        TRUJILLO    NaN  NaN  2024      3     II     2024
# 99605        TRUJILLO    NaN  NaN  2024      3     II     2024
# 99606        TRUJILLO    NaN  NaN  2024      3     II     2024
# 99607        TRUJILLO    NaN  NaN  2024      3     II     2024
# ...               ...    ...  ...   ...    ...    ...      ...
# 107560  STGO.DE CHUCO    NaN  NaN  2024      3     II     2024
# 107561  STGO.DE CHUCO    NaN  NaN  2024      3     II     2024
# 107562  STGO.DE CHUCO    NaN  NaN  2024      3     II     2024
# 107563  STGO.DE CHUCO    NaN  NaN  2024      3     II     2024
# 107564  STGO.DE CHUCO    NaN  NaN  2024      3     II     2024
#
# [7962 rows x 18 columns]

# %%
# puntaje1 = puntaje1.drop(['r2', 'r3', 'r4', 'r5'], axis=1)
puntaje1.rename(columns={'r1': 'puntaje'}, inplace=True)
puntaje1
# Out:
#                                       names  puntaje         escuela  \
# 99603          CASTRO GARCIA PAULO GAMALIEL  147.835  ADMINISTRACION
# 99604            PONCE SALVADOR NAOMI BELEN  126.434  ADMINISTRACION
# 99605          PINTADO PEÑA LUCIANA NICOLLE  124.382  ADMINISTRACION
# 99606        LEZAMA DIAZ JENNIFER ANGHELINA  124.377  ADMINISTRACION
# 99607     ABILA VILLANUEVA ADRIANA AMPARITO  123.361  ADMINISTRACION
# ...                                     ...      ...             ...
# 107560          CASTILLO ROJAS HUGO GABRIEL    4.044   ING.AMBIENTAL
# 107561           RUIZ JACOBO MERLY MILAGROS    0.986   ING.AMBIENTAL
# 107562        ULLOA FLORES MANUEL JHAN FRAN   -0.100   ING.AMBIENTAL
# 107563  CONTRERAS GUTIERREZ BRAYAN MERCEDES   -4.159   ING.AMBIENTAL
# 107564          GARCIA CORONEL YOHAN ESMITH   -7.202   ING.AMBIENTAL
#
#        resultado  n_df            tipo      fecha          lugar alumno area  \
# 99603         SI   186  EXTRAORDINARIO 2024-03-03       TRUJILLO    NaN  NaN
# 99604         SI   186  EXTRAORDINARIO 2024-03-03       TRUJILLO    NaN  NaN
# 99605         SI   186  EXTRAORDINARIO 2024-03-03       TRUJILLO    NaN  NaN
# 99606         SI   186  EXTRAORDINARIO 2024-03-03       TRUJILLO    NaN  NaN
# 99607         SI   186  EXTRAORDINARIO 2024-03-03       TRUJILLO    NaN  NaN
# ...          ...   ...             ...        ...            ...    ...  ...
# 107560        NO   199       ORDINARIO 2024-03-17  STGO.DE CHUCO    NaN  NaN
# 107561        NO   199       ORDINARIO 2024-03-17  STGO.DE CHUCO    NaN  NaN
# 107562        NO   199       ORDINARIO 2024-03-17  STGO.DE CHUCO    NaN  NaN
# 107563        NO   199       ORDINARIO 2024-03-17  STGO.DE CHUCO    NaN  NaN
# 107564        NO   199       ORDINARIO 2024-03-17  STGO.DE CHUCO    NaN  NaN
#
#         year  month number  periodo
# 99603   2024      3     II     2024
# 99604   2024      3     II     2024
# 99605   2024      3     II     2024
# 99606   2024      3     II     2024
# 99607   2024      3     II     2024
# ...      ...    ...    ...      ...
# 107560  2024      3     II     2024
# 107561  2024      3     II     2024
# 107562  2024      3     II     2024
# 107563  2024      3     II     2024
# 107564  2024      3     II     2024
#
# [7962 rows x 14 columns]

# %%
filter_general = (((filter_by_cepunt) & (filter_by_periodo)) | ((filter_by_tipo) & (filter_by_periodo2) & (filter_by_number2))) 

puntaje3 = results_with_titles[~filter_general]

# %%
puntaje3 = puntaje3.drop(['r1', 'r2', 'r4', 'r5'], axis=1)
puntaje3 = puntaje3.rename(columns={'r3': 'puntaje'})
puntaje3
# Out:
#                                     names  puntaje           escuela  \
# 3266           MARCELO SOTO DILMER OLIVER  190.591   CCAS.BIOLOGICAS
# 3267    AREVALO RAMIREZ DULCEMARIA JANINA  136.534   CCAS.BIOLOGICAS
# 3268    RODRIGUEZ SEMINARIO CARMEN EMILIA  115.111   CCAS.BIOLOGICAS
# 3269     RODRIGUEZ PESANTES DAIANA LISETT  115.080   CCAS.BIOLOGICAS
# 3270       DIOSES IBAÑEZ GUILLERMO FRANCO  107.995   CCAS.BIOLOGICAS
# ...                                   ...      ...               ...
# 115380         LAZARO LLANOS RICHARD JOEL   73.996  ED.SEC: HISTORIA
# 115381         ALBUJAR VIERA LUIS ALBERTO   56.455  ED.SEC: HISTORIA
# 115382            POLO REYES JULIO MARTIN   38.721  ED.SEC: HISTORIA
# 115383          ALFARO MEDRANO MARIA JOSE   37.298  ED.SEC: HISTORIA
# 115384           JESUS VEGA CRISTIAN JOEL   25.253  ED.SEC: HISTORIA
#
#        resultado  n_df       tipo      fecha     lugar alumno area  year  \
# 3266          SI     3  ORDINARIO 2018-09-22  TRUJILLO    NaN    A  2018
# 3267          SI     3  ORDINARIO 2018-09-22  TRUJILLO    NaN    A  2018
# 3268          SI     3  ORDINARIO 2018-09-22  TRUJILLO    NaN    A  2018
# 3269          SI     3  ORDINARIO 2018-09-22  TRUJILLO    NaN    A  2018
# 3270          SI     3  ORDINARIO 2018-09-22  TRUJILLO    NaN    A  2018
# ...          ...   ...        ...        ...       ...    ...  ...   ...
# 115380        NO   205     CEPUNT 2024-02-18  TRUJILLO    NaN  NaN  2024
# 115381        NO   205     CEPUNT 2024-02-18  TRUJILLO    NaN  NaN  2024
# 115382        NO   205     CEPUNT 2024-02-18  TRUJILLO    NaN  NaN  2024
# 115383        NO   205     CEPUNT 2024-02-18  TRUJILLO    NaN  NaN  2024
# 115384        NO   205     CEPUNT 2024-02-18  TRUJILLO    NaN  NaN  2024
#
#         month number  periodo
# 3266        9      I     2019
# 3267        9      I     2019
# 3268        9      I     2019
# 3269        9      I     2019
# 3270        9      I     2019
# ...       ...    ...      ...
# 115380      2     II     2024
# 115381      2     II     2024
# 115382      2     II     2024
# 115383      2     II     2024
# 115384      2     II     2024
#
# [95131 rows x 14 columns]

# %% [markdown]
# # UNIENDO PUNTAJES

# %%
final_dirty = pd.concat(
    [
        puntaje1,
        puntaje3,
        puntaje_4
    ]
)
final_dirty
# Out:
#                                    names  puntaje         escuela resultado  \
# 99603       CASTRO GARCIA PAULO GAMALIEL  147.835  ADMINISTRACION        SI
# 99604         PONCE SALVADOR NAOMI BELEN  126.434  ADMINISTRACION        SI
# 99605       PINTADO PEÑA LUCIANA NICOLLE  124.382  ADMINISTRACION        SI
# 99606     LEZAMA DIAZ JENNIFER ANGHELINA  124.377  ADMINISTRACION        SI
# 99607  ABILA VILLANUEVA ADRIANA AMPARITO  123.361  ADMINISTRACION        SI
# ...                                  ...      ...             ...       ...
# 31547           LAYZA SANCHEZ ELVIS ALEX   20.630    ING.DE MINAS        NO
# 31548             INFANTES REYES JONATAN   17.262    ING.DE MINAS        NO
# 31549  SANCHEZ FERNANDEZ SAMUEL JHONATAN   14.354    ING.DE MINAS        NO
# 31550                 CAIPO POLO HILARIO    5.900    ING.DE MINAS        NO
# 31551      SANDOVAL SEGURA DENNI MANFRED   -0.531    ING.DE MINAS        NO
#
#        n_df            tipo      fecha       lugar alumno area  year  month  \
# 99603   186  EXTRAORDINARIO 2024-03-03    TRUJILLO    NaN  NaN  2024      3
# 99604   186  EXTRAORDINARIO 2024-03-03    TRUJILLO    NaN  NaN  2024      3
# 99605   186  EXTRAORDINARIO 2024-03-03    TRUJILLO    NaN  NaN  2024      3
# 99606   186  EXTRAORDINARIO 2024-03-03    TRUJILLO    NaN  NaN  2024      3
# 99607   186  EXTRAORDINARIO 2024-03-03    TRUJILLO    NaN  NaN  2024      3
# ...     ...             ...        ...         ...    ...  ...   ...    ...
# 31547    37          CEPUNT 2020-02-09  HUAMACHUCO    NaN  NaN  2020      2
# 31548    37          CEPUNT 2020-02-09  HUAMACHUCO    NaN  NaN  2020      2
# 31549    37          CEPUNT 2020-02-09  HUAMACHUCO    NaN  NaN  2020      2
# 31550    37          CEPUNT 2020-02-09  HUAMACHUCO    NaN  NaN  2020      2
# 31551    37          CEPUNT 2020-02-09  HUAMACHUCO    NaN  NaN  2020      2
#
#       number  periodo
# 99603     II     2024
# 99604     II     2024
# 99605     II     2024
# 99606     II     2024
# 99607     II     2024
# ...      ...      ...
# 31547     II     2020
# 31548     II     2020
# 31549     II     2020
# 31550     II     2020
# 31551     II     2020
#
# [115385 rows x 14 columns]

# %%
final_dirty = final_dirty.reset_index()
final_dirty = final_dirty.drop(['index', 'n_df', 'year', 'month'], axis=1)
final_dirty
# Out:
#                                     names  puntaje         escuela resultado  \
# 0            CASTRO GARCIA PAULO GAMALIEL  147.835  ADMINISTRACION        SI
# 1              PONCE SALVADOR NAOMI BELEN  126.434  ADMINISTRACION        SI
# 2            PINTADO PEÑA LUCIANA NICOLLE  124.382  ADMINISTRACION        SI
# 3          LEZAMA DIAZ JENNIFER ANGHELINA  124.377  ADMINISTRACION        SI
# 4       ABILA VILLANUEVA ADRIANA AMPARITO  123.361  ADMINISTRACION        SI
# ...                                   ...      ...             ...       ...
# 115380           LAYZA SANCHEZ ELVIS ALEX   20.630    ING.DE MINAS        NO
# 115381             INFANTES REYES JONATAN   17.262    ING.DE MINAS        NO
# 115382  SANCHEZ FERNANDEZ SAMUEL JHONATAN   14.354    ING.DE MINAS        NO
# 115383                 CAIPO POLO HILARIO    5.900    ING.DE MINAS        NO
# 115384      SANDOVAL SEGURA DENNI MANFRED   -0.531    ING.DE MINAS        NO
#
#                   tipo      fecha       lugar alumno area number  periodo
# 0       EXTRAORDINARIO 2024-03-03    TRUJILLO    NaN  NaN     II     2024
# 1       EXTRAORDINARIO 2024-03-03    TRUJILLO    NaN  NaN     II     2024
# 2       EXTRAORDINARIO 2024-03-03    TRUJILLO    NaN  NaN     II     2024
# 3       EXTRAORDINARIO 2024-03-03    TRUJILLO    NaN  NaN     II     2024
# 4       EXTRAORDINARIO 2024-03-03    TRUJILLO    NaN  NaN     II     2024
# ...                ...        ...         ...    ...  ...    ...      ...
# 115380          CEPUNT 2020-02-09  HUAMACHUCO    NaN  NaN     II     2020
# 115381          CEPUNT 2020-02-09  HUAMACHUCO    NaN  NaN     II     2020
# 115382          CEPUNT 2020-02-09  HUAMACHUCO    NaN  NaN     II     2020
# 115383          CEPUNT 2020-02-09  HUAMACHUCO    NaN  NaN     II     2020
# 115384          CEPUNT 2020-02-09  HUAMACHUCO    NaN  NaN     II     2020
#
# [115385 rows x 11 columns]
